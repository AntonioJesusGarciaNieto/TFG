# %% [markdown]
# En este experimiento usaremos la infraestructura planteada para comprobar si las ideas del artículo "" se pueden replicar.

# %% [markdown]
# ##Datos previos

# %% [markdown]
# Librerías usadas.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from glob import glob
from matplotlib import pyplot as plt
import os
import tensorflow as tf
from tqdm import tqdm
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import resample

# %% [markdown]
# Parámetros globales

# %%
#Rutas de los datos.
 
data_dir = os.path.dirname(os.path.realpath("../TFG/Datos/HAM10000_metadata.csv"))



csv_path = os.path.realpath(data_dir + "/HAM10000_metadata.csv")

#Variables globales

altura = 64
longitud = 64
clases = 7


print(data_dir)

print(csv_path)
# Out:
# /home/antoniojesus/Escritorio/TFG/Datos
# /home/antoniojesus/Escritorio/TFG/Datos/HAM10000_metadata.csv

# %% [markdown]
# Creación del marco de datos.

# %%
#Inicializando el dataFrame

dataFrame=pd.read_csv(csv_path)

#Mezclando carpetas.

all_image_path = glob(os.path.join(data_dir, '*', '*'))
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in all_image_path}

# Inicializando diccionario de categorías

lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

#Añadiendo columnas al dataFrame para que sea más legible.

dataFrame['path'] = dataFrame['image_id'].map(imageid_path_dict.get)
dataFrame['cell_type'] = dataFrame['dx'].map(lesion_type_dict.get) 
dataFrame['cell_type_idx'] = pd.Categorical(dataFrame['cell_type']).codes
dataFrame.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path          cell_type  \
# 0  /home/antoniojesus/Escritorio/TFG/Datos/HAM100...  Benign keratosis
# 1  /home/antoniojesus/Escritorio/TFG/Datos/HAM100...  Benign keratosis
# 2  /home/antoniojesus/Escritorio/TFG/Datos/HAM100...  Benign keratosis
# 3  /home/antoniojesus/Escritorio/TFG/Datos/HAM100...  Benign keratosis
# 4  /home/antoniojesus/Escritorio/TFG/Datos/HAM100...  Benign keratosis
#
#    cell_type_idx
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2

# %% [markdown]
# ## Crear red

# %% [markdown]
# ### Select_network

# %%
def select_network(nn_base_arch):

    if nn_base_arch == 'VGG16':
        nn = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(altura, longitud,3))
    if nn_base_arch == 'VGG19':  
        nn = tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(altura, longitud,3))
    if nn_base_arch == 'ResNet50':  
        nn = tf.keras.applications.ResNet50V2(weights='imagenet', include_top=False, input_shape=(altura, longitud,3))
    if nn_base_arch =='CNN':
        nn = cnn_estudio()
    if nn_base_arch =='CNN':
        nn = cnn()
    if nn_base_arch =='CNN_PReLU':
        nn = cnn_PReLU()
        
    return nn

# %% [markdown]
# ###Definición de capas superiores

# %% [markdown]
# Los métodos que se describen acontinuación permitirán crear diferentes tipos capas superiores para las redes:
#
#  - cnn = Crea un red con una estructura basada en dos capas de convolución + maxPooling seguidas de una globalMaxPooling.
#
#  - cnn_PReLU = Es una varicación de la anterior en la que en lugar de usar ReLU como función de activación se usa PReLU.
#
#  - cnn_estudio = Es una réplica de la red usada en el estudio "".

# %%
def cnn():
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.Conv2D(32, 3, 3, activation='relu',input_shape=(altura,longitud,3)))
    model.add(tf.keras.layers.MaxPooling2D((2,2)))

    model.add(tf.keras.layers.Conv2D(32, 3, 3, activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((2,2)))   

    model.add(tf.keras.layers.GlobalMaxPooling2D())
    
    return model

def cnn_estudio():
    
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.Conv2D(32, 3, 3, activation='relu',input_shape=(altura,longitud,3)))
    model.add(tf.keras.layers.MaxPooling2D((2,2)))

    model.add(tf.keras.layers.Conv2D(32, 3, 3, activation='relu'))
    model.add(tf.keras.layers.Conv2D(32, 3, 3, activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D((2,2)))  

    model.add(tf.keras.layers.GlobalMaxPooling2D())
    
    return model

def cnn_PReLU():
    
    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Conv2D(32, 3, 3,input_shape=(altura,longitud,3)))
    #model.add(tf.keras.layers.BatchNormalization(momentum=0.9, gamma_regularizer=tf.keras.regularizers.L2(1e-4)))
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2), padding='same'))


    model.add(tf.keras.layers.Conv2D(32, 3, 3))
    #model.add(tf.keras.layers.BatchNormalization(momentum=0.9, gamma_regularizer=tf.keras.regularizers.L2(1e-4)))  
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.MaxPooling2D((2,2), strides=(2,2), padding='same'))


    #model.add(tf.keras.layers.Conv2D(64, 3, 3))
    #model.add(tf.keras.layers.PReLU())
 
    model.add(tf.keras.layers.GlobalMaxPooling2D())

    return model

# %% [markdown]
# ### Definición de capas de salida

# %% [markdown]
# Los métodos que se describen a continuación generarán la capa de salida de nuestra red :
#  - build_raw : En este caso usaremos dos capas de dropout para acompañar a las dos capas de densidad (512 neuronas)
#  - build : Modificación de la anterior, añadimos una capa de BachNormalization
#  - build_prelu: Modificación de la anterior solo que en este caso sustituimos ReLU por PReLU como función de activación
#  - build_prelu_dense : Modificación de la anterior se duplican las neuronas en la capa de densidad.

# %%
def build_raw(nn):
    model = tf.keras.Sequential()
    
    model.add(nn)
    
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(512))
    model.add(tf.keras.layers.Activation('relu'))

    model.add(tf.keras.layers.Dense(512))
    model.add(tf.keras.layers.Activation('relu'))
  
    model.add(tf.keras.layers.Dropout(0.4))

    model.add(tf.keras.layers.Dense(clases,activation='softmax'))
  
  

    print(model.summary())

    return model

def build(nn):
    model = tf.keras.Sequential()
    model.add(nn)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(512))
    model.add(tf.keras.layers.Activation('relu'))

    model.add(tf.keras.layers.Dense(512))
    model.add(tf.keras.layers.Activation('relu'))
  
    model.add(tf.keras.layers.BatchNormalization())
  
    model.add(tf.keras.layers.Dropout(0.4))

    model.add(tf.keras.layers.Dense(clases,activation='softmax'))
  
  

    print(model.summary())

    return model

def build_prelu_dense(nn):
    model = tf.keras.Sequential()
    model.add(nn)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.4))

    model.add(tf.keras.layers.Dense(1024))
    model.add(tf.keras.layers.PReLU())
    
    model.add(tf.keras.layers.Dense(1024))
    model.add(tf.keras.layers.PReLU())
    
    model.add(tf.keras.layers.BatchNormalization())
  
    model.add(tf.keras.layers.Dropout(0.5))

    model.add(tf.keras.layers.Dense(clases,activation='softmax'))
  
  

    print(model.summary())

    return model

def build_prelu(nn):
    model = tf.keras.Sequential()
    model.add(nn)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(512))
    model.add(tf.keras.layers.PReLU())

    model.add(tf.keras.layers.Dense(512))
    model.add(tf.keras.layers.PReLU())
  
    model.add(tf.keras.layers.BatchNormalization())
  
    model.add(tf.keras.layers.Dropout(0.4))

    model.add(tf.keras.layers.Dense(clases,activation='softmax'))
  
  

    print(model.summary())

    return model

# %% [markdown]
# ##Balanceo y carga de datos

# %% [markdown]
# Se procede a crear un método que permita balancear la carga de imágenes

# %%
def balanced_dataset(df):
    df_balanced = pd.DataFrame()
    #df = pd.DataFrame()
    
    for cat in df['cell_type_idx'].unique():
        temp = resample(df[df['cell_type_idx'] == cat], 
                        replace=True,     # sample with replacement
                        n_samples=2500,   # to match majority class
                        random_state=123) # reproducible results

        # Combine majority class with upsampled minority class
        df_balanced = pd.concat([df_balanced, temp])
 
    df_balanced['cell_type'].value_counts()

    return df_balanced

def load_img_data(size, df, balanced=False):
    """
        ..
        first we should normalize the image from 0-255 to 0-1
    """
    
    img_h, img_w = size, size
    imgs = []
    
    if balanced:
        df = balanced_dataset(df)
    
    image_paths = list(df['path'])

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        img = img.astype(np.float32) / 255.
        #img = np.asarray(Image.open(image_paths[i]).resize((size,size)))
        imgs.append(img)

    imgs = np.stack(imgs, axis=0)
    print(imgs.shape)

    #imgs = imgs.astype(np.float32) / 255.
    
    return imgs, df['cell_type_idx'].values

# %%
del dataFrame
del imgs
del target
del x_train
del x_test
del y_train
del y_test
del x_val
del y_val

# %%
imgs, target = load_img_data(altura, dataFrame, balanced=True)
# Out:
# 100%|██████████| 17500/17500 [03:45<00:00, 77.58it/s]
# (17500, 64, 64, 3)

# %%
x_train, x_test, y_train, y_test = train_test_split(imgs, target, test_size=0.20)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.05)

train_val_test = (x_train, y_train, x_val, y_val, x_test, y_test)

[x_train.shape, x_val.shape, x_test.shape]

trainX = train_val_test[0]
trainY = train_val_test[1]
valX = train_val_test[2]
valY = train_val_test[3]
testX = train_val_test[4]
testY = train_val_test[5]

numTrainingSamples = trainX.shape[0]
numValidationSamples = valX.shape[0]

# %% [markdown]
# ## Otros parámetros

# %%
mini_batch_size =numTrainingSamples/875
mbs=int(mini_batch_size)
mbs
# Out:
# 15

# %%
optAMSGrad = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="AMSGrad"

)

# %% [markdown]
# ##Definición de métodos de entrenamieto

# %%
def run_train(nn_base_arch,checkpoint,epocas,raw = False,prelu = False,high_dense = False):
    nn = select_network(nn_base_arch)
    
    if high_dense == True : 
        model = build_prelu_dense(nn)
    
    if raw == True : 
        model = build_raw(nn)
        
    elif prelu == True : 
        model = build_prelu(nn)
        
    else: 
        model = build(nn)
        
    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optAMSGrad, metrics=['accuracy','mse'])
    history = model.fit(x_train, y_train,steps_per_epoch=(numTrainingSamples/(mbs*25)),epochs=epocas,validation_data=(valX, valY),callbacks=[checkpoint],batch_size = mbs)
  
    return history

def re_train(model,checkpoint,epocas):
    checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
    history = model.fit(x_train, y_train,steps_per_epoch=(numTrainingSamples/(mbs*25)),epochs=epocas,validation_data=(valX, valY),callbacks=[checkpoint],batch_size = mbs)
  
    return history

# %% [markdown]
# ##Entrenamiento

# %%
epocas = 12000
nn_base_arch = "CNN_PReLU"
checkpoint ="../TFG/Modelos/balanced_model_"+nn_base_arch+"_PP_HH_ph2_weights.h5"
history = run_train(nn_base_arch,checkpoint,epocas,raw = False, prelu = False, high_dense = True)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_17 (Sequential)   (None, 32)                24544
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_31 (Dense)             (None, 2048)              67584
# _________________________________________________________________
# p_re_lu_25 (PReLU)           (None, 2048)              2048
# _________________________________________________________________
# dense_32 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# p_re_lu_26 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_33 (Dense)             (None, 512)               524800
# _________________________________________________________________
# p_re_lu_27 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_34 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_28 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_35 (Dense)             (None, 2048)              2099200
# _________________________________________________________________
# p_re_lu_29 (PReLU)           (None, 2048)              2048
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 2048)              8192
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 7)                 14343
# =================================================================
# Total params: 5,368,807
# Trainable params: 5,364,711
# Non-trainable params: 4,096
# _________________________________________________________________
# None
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_17 (Sequential)   (None, 32)                24544
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 32)                0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               16896
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 512)               262656
# _________________________________________________________________
# activation_9 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 7)                 3591
# =================================================================
# Total params: 309,735
# Trainable params: 308,711
# Non-trainable params: 1,024
# _________________________________________________________________
# None
# Epoch 1/12000
# 35/35 [============================>.] - ETA: 0s - loss: 2.0805 - accuracy: 0.1676 - mse: 12.5733
# Epoch 00001: val_loss improved from inf to 1.94871, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s 16ms/step - loss: 2.0754 - accuracy: 0.1648 - mse: 12.4947 - val_loss: 1.9487 - val_accuracy: 0.1943 - val_mse: 12.5817
# Epoch 2/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 1.9530 - accuracy: 0.1737 - mse: 12.8822
# Epoch 00002: val_loss improved from 1.94871 to 1.93456, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s 21ms/step - loss: 1.9476 - accuracy: 0.1741 - mse: 12.5036 - val_loss: 1.9346 - val_accuracy: 0.1400 - val_mse: 12.5815
# Epoch 3/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.8823 - accuracy: 0.1933 - mse: 12.9266
# Epoch 00003: val_loss did not improve from 1.93456
# 36/35 [==============================] - 0s 10ms/step - loss: 1.8854 - accuracy: 0.1944 - mse: 12.8332 - val_loss: 1.9398 - val_accuracy: 0.1400 - val_mse: 12.5815
# Epoch 4/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.8875 - accuracy: 0.2289 - mse: 12.5712
# Epoch 00004: val_loss did not improve from 1.93456
# 36/35 [==============================] - 0s 10ms/step - loss: 1.8743 - accuracy: 0.2407 - mse: 12.3729 - val_loss: 1.9355 - val_accuracy: 0.2143 - val_mse: 12.5814
# Epoch 5/12000
# 35/35 [============================>.] - ETA: 0s - loss: 1.8352 - accuracy: 0.2133 - mse: 11.8433
# Epoch 00005: val_loss improved from 1.93456 to 1.93085, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s
12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.5356 - accuracy: 0.3422 - mse: 10.8967
# Epoch 00035: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 10ms/step - loss: 1.5382 - accuracy: 0.3481 - mse: 10.9574 - val_loss: 1.3851 - val_accuracy: 0.4514 - val_mse: 12.6075
# Epoch 36/12000
# 35/35 [============================>.] - ETA: 0s - loss: 1.4052 - accuracy: 0.4133 - mse: 12.8830
# Epoch 00036: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4096 - accuracy: 0.4093 - mse: 12.7589 - val_loss: 1.6783 - val_accuracy: 0.3700 - val_mse: 12.6270
# Epoch 37/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.5378 - accuracy: 0.4024 - mse: 12.6249
# Epoch 00037: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 9ms/step - loss: 1.5468 - accuracy: 0.3944 - mse: 12.5048 - val_loss: 1.9843 - val_accuracy: 0.3329 - val_mse: 12.6189
# Epoch 38/12000
# 36/35 [==============================] - ETA: 0s - loss: 1.5615 - accuracy: 0.3815 - mse: 11.5503
# Epoch 00038: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 9ms/step - loss: 1.5615 - accuracy: 0.3815 - mse: 11.5503 - val_loss: 1.8284 - val_accuracy: 0.2657 - val_mse: 12.6129
# Epoch 39/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.5274 - accuracy: 0.3881 - mse: 11.7519
# Epoch 00039: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 9ms/step - loss: 1.5316 - accuracy: 0.3796 - mse: 11.4526 - val_loss: 1.4055 - val_accuracy: 0.4114 - val_mse: 12.6044
# Epoch 40/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.4612 - accuracy: 0.4048 - mse: 13.1128
# Epoch 00040: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4452 - accuracy: 0.3981 - mse: 13.0580 - val_loss: 1.8031 - val_accuracy: 0.2957 - val_mse: 12.6255
# Epoch 41/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.4313 - accuracy: 0.3905 - mse: 12.8854
# Epoch 00041: val_loss did not improve from 1.38261
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4725 - accuracy: 0.3704 - mse: 12.5216 - val_loss: 1.9869 - val_accuracy: 0.2286 - val_mse: 12.6217
# Epoch 42/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.4937 - accuracy: 0.3738 - mse: 12.1467
# Epoch 00042: val_loss improved from 1.38261 to 1.36386, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s 20ms/step - loss: 1.4702 - accuracy: 0.3889 - mse: 12.1781 - val_loss: 1.3639 - val_accuracy: 0.4243 - val_mse: 12.6142
# Epoch 43/12000
# 35/35 [============================>.] - ETA: 0s - loss: 1.4938 - accuracy: 0.4076 - mse: 12.6414
# Epoch 00043: val_loss did not improve from 1.36386
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4846 - accuracy: 0.4111 - mse: 12.8851 - val_loss: 1.8450 - val_accuracy: 0.3343 - val_mse: 12.6227
# Epoch 44/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.4652 - accuracy: 0.4119 - mse: 11.8355
# Epoch 00044: val_loss did not improve from 1.36386
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4572 - accuracy: 0.4056 - mse: 11.9790 - val_loss: 1.6937 - val_accuracy: 0.3471 - val_mse: 12.6210
# Epoch 45/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.4255 - accuracy: 0.4048 - mse: 12.3899
# Epoch 00045: val_loss did not improve from 1.36386
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4321 - accuracy: 0.4167 - mse: 12.3449 - val_loss: 1.4826 - val_accuracy: 0.3900 - val_mse: 12.6141
# Epoch 46/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.4762 - accuracy: 0.3762 - mse: 11.3852
# Epoch 00046: val_loss did not improve from 1.36386
# 36/35 [==============================] - 0s 9ms/step - loss: 1.4811 - accuracy: 0.3944 - mse: 11.5685 - val_loss: 1.5516 - val_accuracy: 0.3671 - val_mse: 12.6134
# Epoch 47/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.
12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3675 - accuracy: 0.4476 - mse: 12.3626
# Epoch 00085: val_loss did not improve from 1.24626
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3709 - accuracy: 0.4352 - mse: 12.0573 - val_loss: 1.4719 - val_accuracy: 0.4257 - val_mse: 12.6120
# Epoch 86/12000
# 36/35 [==============================] - ETA: 0s - loss: 1.3681 - accuracy: 0.4574 - mse: 12.2948
# Epoch 00086: val_loss did not improve from 1.24626
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3681 - accuracy: 0.4574 - mse: 12.2948 - val_loss: 1.8051 - val_accuracy: 0.3429 - val_mse: 12.6223
# Epoch 87/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3064 - accuracy: 0.4595 - mse: 12.1094
# Epoch 00087: val_loss did not improve from 1.24626
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3203 - accuracy: 0.4500 - mse: 11.4416 - val_loss: 1.3370 - val_accuracy: 0.4414 - val_mse: 12.6162
# Epoch 88/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3169 - accuracy: 0.4881 - mse: 12.9400
# Epoch 00088: val_loss improved from 1.24626 to 1.22444, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s 24ms/step - loss: 1.3004 - accuracy: 0.4907 - mse: 12.6634 - val_loss: 1.2244 - val_accuracy: 0.5371 - val_mse: 12.6125
# Epoch 89/12000
# 31/35 [=========================>....] - ETA: 0s - loss: 1.3354 - accuracy: 0.4215 - mse: 11.2537
# Epoch 00089: val_loss did not improve from 1.22444
# 36/35 [==============================] - 0s 10ms/step - loss: 1.3296 - accuracy: 0.4278 - mse: 11.5562 - val_loss: 1.3594 - val_accuracy: 0.4629 - val_mse: 12.6191
# Epoch 90/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.3119 - accuracy: 0.4851 - mse: 11.8124
# Epoch 00090: val_loss did not improve from 1.22444
# 36/35 [==============================] - 0s 8ms/step - loss: 1.2954 - accuracy: 0.4889 - mse: 11.8467 - val_loss: 1.4450 - val_accuracy: 0.4071 - val_mse: 12.6226
# Epoch 91/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3721 - accuracy: 0.4548 - mse: 11.2859
# Epoch 00091: val_loss did not improve from 1.22444
# 36/35 [==============================] - 0s 8ms/step - loss: 1.3538 - accuracy: 0.4630 - mse: 11.8840 - val_loss: 1.2427 - val_accuracy: 0.4786 - val_mse: 12.6186
# Epoch 92/12000
# 36/35 [==============================] - ETA: 0s - loss: 1.3474 - accuracy: 0.4704 - mse: 12.1623
# Epoch 00092: val_loss improved from 1.22444 to 1.19975, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 2s 46ms/step - loss: 1.3474 - accuracy: 0.4704 - mse: 12.1623 - val_loss: 1.1998 - val_accuracy: 0.5114 - val_mse: 12.6150
# Epoch 93/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.3655 - accuracy: 0.4644 - mse: 11.7376
# Epoch 00093: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3568 - accuracy: 0.4593 - mse: 11.7454 - val_loss: 1.5044 - val_accuracy: 0.4057 - val_mse: 12.6273
# Epoch 94/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.2751 - accuracy: 0.5195 - mse: 12.4986
# Epoch 00094: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 8ms/step - loss: 1.2898 - accuracy: 0.5019 - mse: 12.5590 - val_loss: 1.2407 - val_accuracy: 0.4929 - val_mse: 12.6193
# Epoch 95/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3627 - accuracy: 0.4619 - mse: 11.6691
# Epoch 00095: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 8ms/step - loss: 1.3559 - accuracy: 0.4574 - mse: 11.6761 - val_loss: 1.2914 - val_accuracy: 0.4743 - val_mse: 12.6142
# Epoch 96/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.3769 - accuracy: 0.4736 - mse: 12.8394
# Epoch 00096: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 8ms/step - loss: 1.3617 - accuracy: 0.4796 - mse: 12.8307 - val_loss: 1.3013 - val_accuracy: 0.4771 - val_mse: 12.6167
# Epoch 97/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.2966 - accuracy: 0.4690 - mse: 13.1656
# Epoch 00097: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 8ms/step - loss: 1.3005 - accuracy: 0.4833 - mse: 13.1047 - val_loss: 1.8809 - val_accuracy: 0.3157 - val_mse: 12.6281
# Epoch 98/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.3054 - accuracy: 0.4689 - mse: 11.9793
# Epoch 00098: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 8ms/step - loss: 1.3023 - accuracy: 0.4722 - mse: 11.9519 - val_loss: 1.2426 - val_accuracy: 0.5114 - val_mse: 12.6167
# Epoch 99/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.3447 - accuracy: 0.4876 - mse: 11.4273
# Epoch 00099: val_loss did not improve from 1.19975
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3336 - accuracy: 0.4879 - mse: 11.7236 - val_loss: 1.4002 - val_accuracy: 0.4371 - val_mse: 12.6214
# Epoch 100/12000
# 27/35 [=====================>........] - ETA: 0s - loss: 1.2908 - accuracy: 0.4593 - mse: 12.2895
# Epoch 00100: val_loss improved from 1.19975 to 1.18165, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s 23ms/step - loss: 1.3176 - accuracy: 0.4519 - mse: 12.1788 - val_loss: 1.1817 - val_accuracy: 0.5114 - val_mse: 12.6185
# Epoch 101/12000
# 35/35 [============================>.] - ETA: 0s - loss: 1.2908 - accuracy: 0.4857 - mse: 11.0823
# Epoch 00101: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 11ms/step - loss: 1.2890 - accuracy: 0.4852 - mse: 11.0747 - val_loss: 1.2182 - val_accuracy: 0.5357 - val_mse: 12.6126
# Epoch 102/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 1.3468 - accuracy: 0.4588 - mse: 12.0033
# Epoch 00102: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3344 - accuracy: 0.4611 - mse: 12.0767 - val_loss: 1.2493 - val_accuracy: 0.5014 - val_mse: 12.6195
# Epoch 103/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 1.2880 - accuracy: 0.4586 - mse: 12.1415
# Epoch 00103: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.3096 - accuracy: 0.4481 - mse: 11.9505 - val_loss: 1.2335 - val_accuracy: 0.5329 - val_mse: 12.6154
# Epoch 104/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 1.3221 - accuracy: 0.4606 - mse: 11.6739
# Epoch 00104: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.3176 - accuracy: 0.4519 - mse: 11.7261 - val_loss: 1.3971 - val_accuracy: 0.4671 - val_mse: 12.6053
# Epoch 105/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 1.2480 - accuracy: 0.5196 - mse: 11.8257
# Epoch 00105: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.2449 - accuracy: 0.5222 - mse: 11.8153 - val_loss: 1.2520 - val_accuracy: 0.4800 - val_mse: 12.6228
# Epoch 106/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 1.2768 - accuracy: 0.5059 - mse: 11.8068
# Epoch 00106: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.2796 - accuracy: 0.5093 - mse: 11.9510 - val_loss: 1.2489 - val_accuracy: 0.4857 - val_mse: 12.6176
# Epoch 107/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 1.2876 - accuracy: 0.4828 - mse: 12.3118
# Epoch 00107: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2881 - accuracy: 0.4796 - mse: 12.3040 - val_loss: 1.1978 - val_accuracy: 0.5143 - val_mse: 12.6192
# Epoch 108/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 1.2866 - accuracy: 0.4902 - mse: 12.8279
# Epoch 00108: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.2937 - accuracy: 0.4889 - mse: 12.9263 - val_loss: 1.2541 - val_accuracy: 0.4443 - val_mse: 12.6161
# Epoch 109/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 1.2824 - accuracy: 0.5010 - mse: 11.9215
# Epoch 00109: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.2920 - accuracy: 0.5000 - mse: 11.7954 - val_loss: 1.2578 - val_accuracy: 0.4814 - val_mse: 12.6219
# Epoch 110/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 1.2388 - accuracy: 0.5059 - mse: 12.2287
# Epoch 00110: val_loss did not improve from 1.18165
# 36/35 [==============================] - 0s 10ms/step - loss: 1.2298 - accuracy: 0.5074 - mse: 12.2992 - val_loss: 1.1993 - val_accuracy: 0.5100 - val_mse: 12.6207
# Epoch 111/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 1.3357 - accuracy: 0.4606 - mse: 12.2123
# Epoch 00111: val_loss improved from 1.18165 to 1.14080, saving model to ../TFG/Modelos/balanced_model_CNN_PReLU_PP_HH_ph2_weights.h5
# 36/35 [==============================] - 1s 19ms/step - loss: 1.3134 - accuracy: 0.4667 - mse: 12.3246 - val_loss: 1.1408 - val_accuracy: 0.5329 - val_mse: 12.6190
# Epoch 112/12000
# 31/35 [=========================>....] - ETA: 0s - loss: 1.2770 - accuracy: 0.4796 - mse: 11.9386
# Epoch 00112: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 8ms/step - loss: 1.2793 - accuracy: 0.4685 - mse: 11.8855 - val_loss: 1.2446 - val_accuracy: 0.4929 - val_mse: 12.6143
# Epoch 113/12000
# 31/35 [=========================>....] - ETA: 0s - loss: 1.2261 - accuracy: 0.4925 - mse: 11.9454
# Epoch 00113: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 8ms/step - loss: 1.2317 - accuracy: 0.4870 - mse: 12.0935 - val_loss: 1.3688 - val_accuracy: 0.4586 - val_mse: 12.6272
# Epoch 114/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 1.3434 - accuracy: 0.4844 - mse: 13.1573
# Epoch 00114: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 8ms/step - loss: 1.3410 - accuracy: 0.4778 - mse: 12.8628 - val_loss: 1.1549 - val_accuracy: 0.5429 - val_mse: 12.6150
# Epoch 115/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.2389 - accuracy: 0.5011 - mse: 12.3786
# Epoch 00115: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2742 - accuracy: 0.4907 - mse: 11.9968 - val_loss: 1.1462 - val_accuracy: 0.5243 - val_mse: 12.6206
# Epoch 116/12000
# 35/35 [============================>.] - ETA: 0s - loss: 1.3007 - accuracy: 0.4762 - mse: 12.4899
# Epoch 00116: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3066 - accuracy: 0.4759 - mse: 12.4443 - val_loss: 1.1800 - val_accuracy: 0.5114 - val_mse: 12.6222
# Epoch 117/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.2825 - accuracy: 0.4881 - mse: 12.7437
# Epoch 00117: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2573 - accuracy: 0.4907 - mse: 13.1155 - val_loss: 1.1920 - val_accuracy: 0.5071 - val_mse: 12.6227
# Epoch 118/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.2472 - accuracy: 0.4929 - mse: 12.3428
# Epoch 00118: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2735 - accuracy: 0.4870 - mse: 12.3572 - val_loss: 1.2149 - val_accuracy: 0.4971 - val_mse: 12.6191
# Epoch 119/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3572 - accuracy: 0.4595 - mse: 12.0585
# Epoch 00119: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3067 - accuracy: 0.4778 - mse: 12.3010 - val_loss: 1.2149 - val_accuracy: 0.4857 - val_mse: 12.6197
# Epoch 120/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3478 - accuracy: 0.4429 - mse: 12.5943
# Epoch 00120: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3287 - accuracy: 0.4500 - mse: 12.4241 - val_loss: 1.3355 - val_accuracy: 0.4557 - val_mse: 12.6239
# Epoch 121/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.2634 - accuracy: 0.5126 - mse: 12.3171
# Epoch 00121: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2508 - accuracy: 0.5130 - mse: 12.1672 - val_loss: 1.2146 - val_accuracy: 0.5029 - val_mse: 12.6236
# Epoch 122/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.3211 - accuracy: 0.4690 - mse: 12.6877
# Epoch 00122: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3064 - accuracy: 0.4815 - mse: 12.3887 - val_loss: 1.4424 - val_accuracy: 0.4543 - val_mse: 12.6239
# Epoch 123/12000
# 36/35 [==============================] - ETA: 0s - loss: 1.1502 - accuracy: 0.5463 - mse: 12.8044
# Epoch 00123: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.1502 - accuracy: 0.5463 - mse: 12.8044 - val_loss: 1.2123 - val_accuracy: 0.5229 - val_mse: 12.6280
# Epoch 124/12000
# 36/35 [==============================] - ETA: 0s - loss: 1.2645 - accuracy: 0.4879 - mse: 12.6368
# Epoch 00124: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2645 - accuracy: 0.4879 - mse: 12.6368 - val_loss: 1.1444 - val_accuracy: 0.5186 - val_mse: 12.6235
# Epoch 125/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.2753 - accuracy: 0.5190 - mse: 12.4399
# Epoch 00125: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2786 - accuracy: 0.5167 - mse: 12.3156 - val_loss: 1.1444 - val_accuracy: 0.5457 - val_mse: 12.6216
# Epoch 126/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.2961 - accuracy: 0.4833 - mse: 12.6050
# Epoch 00126: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.3072 - accuracy: 0.4759 - mse: 12.5343 - val_loss: 1.1935 - val_accuracy: 0.5329 - val_mse: 12.6210
# Epoch 127/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.2199 - accuracy: 0.5429 - mse: 12.1897
# Epoch 00127: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 9ms/step - loss: 1.2162 - accuracy: 0.5444 - mse: 12.4330 - val_loss: 1.1716 - val_accuracy: 0.5171 - val_mse: 12.6178
# Epoch 128/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 1.2979 - accuracy: 0.4644 - mse: 13.0462
# Epoch 00128: val_loss did not improve from 1.14080
# 36/35 [==============================] - 0s 8ms/step - loss: 1.2830 - accuracy: 0.4833 - mse: 12.8003 - val_loss: 1.2409 - val_accuracy: 0.4614 - val_mse: 12.6207
# Epoch 129/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 1.2460 - accuracy: 0.4857 - mse: 12.7479
# Epoch 00129: val_loss did not improve from 1.14080
# ...
# 28/35 [======================>.......] - ETA: 0s - loss: 0.2584 - accuracy: 0.9119 - mse: 12.0064
# Epoch 02989: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2654 - accuracy: 0.9019 - mse: 12.0248 - val_loss: 0.3547 - val_accuracy: 0.8786 - val_mse: 12.6824
# Epoch 2990/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.3548 - accuracy: 0.8909 - mse: 11.2382
# Epoch 02990: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.3631 - accuracy: 0.8870 - mse: 11.2576 - val_loss: 0.2604 - val_accuracy: 0.9129 - val_mse: 12.6873
# Epoch 2991/12000
# 31/35 [=========================>....] - ETA: 0s - loss: 0.2378 - accuracy: 0.9183 - mse: 13.3105
# Epoch 02991: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.2293 - accuracy: 0.9204 - mse: 13.1861 - val_loss: 0.2815 - val_accuracy: 0.9086 - val_mse: 12.6859
# Epoch 2992/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 0.3159 - accuracy: 0.8843 - mse: 12.8685
# Epoch 02992: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 12ms/step - loss: 0.3056 - accuracy: 0.8889 - mse: 12.7207 - val_loss: 0.2759 - val_accuracy: 0.9029 - val_mse: 12.6872
# Epoch 2993/12000
# 32/35 [==========================>...] - ETA: 0s - loss: 0.2369 - accuracy: 0.9271 - mse: 12.0425
# Epoch 02993: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2326 - accuracy: 0.9259 - mse: 12.0388 - val_loss: 0.3087 - val_accuracy: 0.8886 - val_mse: 12.6835
# Epoch 2994/12000
# 32/35 [==========================>...] - ETA: 0s - loss: 0.3271 - accuracy: 0.8979 - mse: 12.5751
# Epoch 02994: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.3106 - accuracy: 0.9019 - mse: 12.6434 - val_loss: 0.3035 - val_accuracy: 0.8914 - val_mse: 12.6845
# Epoch 2995/12000
# 32/35 [==========================>...] - ETA: 0s - loss: 0.3149 - accuracy: 0.8896 - mse: 12.4569
# Epoch 02995: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.3174 - accuracy: 0.8870 - mse: 12.5642 - val_loss: 0.2719 - val_accuracy: 0.9043 - val_mse: 12.6860
# Epoch 2996/12000
# 31/35 [=========================>....] - ETA: 0s - loss: 0.2484 - accuracy: 0.9097 - mse: 12.1066
# Epoch 02996: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2604 - accuracy: 0.9019 - mse: 12.0705 - val_loss: 0.2683 - val_accuracy: 0.9157 - val_mse: 12.6882
# Epoch 2997/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 0.2500 - accuracy: 0.9178 - mse: 11.9511
# Epoch 02997: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.2395 - accuracy: 0.9222 - mse: 11.9529 - val_loss: 0.2599 - val_accuracy: 0.9129 - val_mse: 12.6861
# Epoch 2998/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.2456 - accuracy: 0.9212 - mse: 12.4359
# Epoch 02998: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2454 - accuracy: 0.9241 - mse: 12.2865 - val_loss: 0.2369 - val_accuracy: 0.9214 - val_mse: 12.6875
# Epoch 2999/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 0.2351 - accuracy: 0.9098 - mse: 12.2315
# Epoch 02999: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2393 - accuracy: 0.9074 - mse: 12.3230 - val_loss: 0.2340 - val_accuracy: 0.9157 - val_mse: 12.6856
# Epoch 3000/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.3235 - accuracy: 0.8869 - mse: 11.6114
# Epoch 03000: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.3236 - accuracy: 0.8852 - mse: 11.3408 - val_loss: 0.2684 - val_accuracy: 0.9086 - val_mse: 12.6880
# Epoch 3001/12000
# 35/35 [============================>.] - ETA: 0s - loss: 0.2830 - accuracy: 0.9086 - mse: 12.2001
# Epoch 03001: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2791 - accuracy: 0.9093 - mse: 12.1213 - val_loss: 0.2869 - val_accuracy: 0.9071 - val_mse: 12.6871
# Epoch 3002/12000
# 36/35 [==============================] - ETA: 0s - loss: 0.3534 - accuracy: 0.8907 - mse: 12.0734
# Epoch 03002: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.3534 - accuracy: 0.8907 - mse: 12.0734 - val_loss: 0.2844 - val_accuracy: 0.9071 - val_mse: 12.6873
# Epoch 3003/12000
# 28/35 [======================>.......] - ETA: 0s - loss: 0.2588 - accuracy: 0.9048 - mse: 11.9414
# Epoch 03003: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2744 - accuracy: 0.9056 - mse: 12.1763 - val_loss: 0.2494 - val_accuracy: 0.9129 - val_mse: 12.6879
# Epoch 3004/12000
# 36/35 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8778 - mse: 12.3103
# Epoch 03004: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.3185 - accuracy: 0.8778 - mse: 12.3103 - val_loss: 0.2566 - val_accuracy: 0.9029 - val_mse: 12.6862
# Epoch 3005/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 0.2405 - accuracy: 0.9039 - mse: 12.0371
# Epoch 03005: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2399 - accuracy: 0.9056 - mse: 12.2052 - val_loss: 0.2417 - val_accuracy: 0.9057 - val_mse: 12.6880
# Epoch 3006/12000
# 36/35 [==============================] - ETA: 0s - loss: 0.3301 - accuracy: 0.8841 - mse: 12.8441
# Epoch 03006: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.3301 - accuracy: 0.8841 - mse: 12.8441 - val_loss: 0.2360 - val_accuracy: 0.9100 - val_mse: 12.6879
# Epoch 3007/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 0.2800 - accuracy: 0.9000 - mse: 11.8379
# Epoch 03007: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2725 - accuracy: 0.9019 - mse: 11.9341 - val_loss: 0.2612 - val_accuracy: 0.9129 - val_mse: 12.6859
# Epoch 3008/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.2839 - accuracy: 0.9051 - mse: 12.3447
# Epoch 03008: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2876 - accuracy: 0.9019 - mse: 12.2505 - val_loss: 0.2679 - val_accuracy: 0.9014 - val_mse: 12.6847
# Epoch 3009/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 0.2725 - accuracy: 0.9000 - mse: 11.4191
# Epoch 03009: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2508 - accuracy: 0.9093 - mse: 11.7318 - val_loss: 0.2899 - val_accuracy: 0.8943 - val_mse: 12.6859
# Epoch 3010/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 0.2734 - accuracy: 0.9126 - mse: 12.5546
# Epoch 03010: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.2824 - accuracy: 0.9074 - mse: 12.8672 - val_loss: 0.2982 - val_accuracy: 0.9000 - val_mse: 12.6834
# Epoch 3011/12000
# 36/35 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8944 - mse: 11.7074
# Epoch 03011: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 12ms/step - loss: 0.2901 - accuracy: 0.8944 - mse: 11.7074 - val_loss: 0.2811 - val_accuracy: 0.8971 - val_mse: 12.6835
# Epoch 3012/12000
# 36/35 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9222 - mse: 12.3446
# Epoch 03012: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.2239 - accuracy: 0.9222 - mse: 12.3446 - val_loss: 0.2448 - val_accuracy: 0.9186 - val_mse: 12.6874
# Epoch 3013/12000
# 29/35 [=======================>......] - ETA: 0s - loss: 0.2380 - accuracy: 0.9241 - mse: 12.8068
# Epoch 03013: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.2391 - accuracy: 0.9222 - mse: 12.3189 - val_loss: 0.3346 - val_accuracy: 0.8771 - val_mse: 12.6837
# Epoch 3014/12000
# 36/35 [==============================] - ETA: 0s - loss: 0.3600 - accuracy: 0.8778 - mse: 12.6847
# Epoch 03014: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.3600 - accuracy: 0.8778 - mse: 12.6847 - val_loss: 0.3104 - val_accuracy: 0.8971 - val_mse: 12.6834
# Epoch 3015/12000
# 32/35 [==========================>...] - ETA: 0s - loss: 0.2776 - accuracy: 0.9021 - mse: 10.8025
# Epoch 03015: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2603 - accuracy: 0.9093 - mse: 11.0148 - val_loss: 0.2785 - val_accuracy: 0.8971 - val_mse: 12.6866
# Epoch 3016/12000
# 35/35 [============================>.] - ETA: 0s - loss: 0.2637 - accuracy: 0.9105 - mse: 11.8109
# Epoch 03016: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 9ms/step - loss: 0.2594 - accuracy: 0.9130 - mse: 11.9129 - val_loss: 0.2716 - val_accuracy: 0.9029 - val_mse: 12.6880
# Epoch 3017/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.2664 - accuracy: 0.9152 - mse: 12.5133
# Epoch 03017: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2603 - accuracy: 0.9167 - mse: 12.6261 - val_loss: 0.2673 - val_accuracy: 0.9143 - val_mse: 12.6852
# Epoch 3018/12000
# 31/35 [=========================>....] - ETA: 0s - loss: 0.2560 - accuracy: 0.9161 - mse: 12.8022
# Epoch 03018: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2520 - accuracy: 0.9185 - mse: 12.7843 - val_loss: 0.3988 - val_accuracy: 0.8443 - val_mse: 12.6818
# Epoch 3019/12000
# 32/35 [==========================>...] - ETA: 0s - loss: 0.2904 - accuracy: 0.8979 - mse: 13.3087
# Epoch 03019: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 11ms/step - loss: 0.2913 - accuracy: 0.9000 - mse: 13.3725 - val_loss: 0.2989 - val_accuracy: 0.8900 - val_mse: 12.6845
# Epoch 3020/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 0.3228 - accuracy: 0.8933 - mse: 12.4321
# Epoch 03020: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.3286 - accuracy: 0.8926 - mse: 12.2196 - val_loss: 0.2605 - val_accuracy: 0.9043 - val_mse: 12.6890
# Epoch 3021/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.3105 - accuracy: 0.8929 - mse: 12.8448
# Epoch 03021: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.3063 - accuracy: 0.8944 - mse: 12.7500 - val_loss: 0.2527 - val_accuracy: 0.9200 - val_mse: 12.6881
# Epoch 3022/12000
# 34/35 [===========================>..] - ETA: 0s - loss: 0.2555 - accuracy: 0.9118 - mse: 11.9153
# Epoch 03022: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2600 - accuracy: 0.9130 - mse: 12.0517 - val_loss: 0.2383 - val_accuracy: 0.9200 - val_mse: 12.6877
# Epoch 3023/12000
# 33/35 [==========================>...] - ETA: 0s - loss: 0.2488 - accuracy: 0.9152 - mse: 12.3725
# Epoch 03023: val_loss did not improve from 0.22319
# 36/35 [==============================] - 0s 10ms/step - loss: 0.2368 - accuracy: 0.9204 - mse: 12.4588 - val_loss: 0.2448 - val_accuracy: 0.9071 - val_mse: 12.6865
# Epoch 3024/12000
# 30/35 [========================>.....] - ETA: 0s - loss: 0.3431 - accuracy: 0.8800 - mse: 12.0450
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-2bfe23b728f9> in <module>
#       2 nn_base_arch = "CNN_PReLU"
#       3 checkpoint ="../TFG/Modelos/balanced_model_"+nn_base_arch+"_PP_HH_ph2_weights.h5"
# ----> 4 history = run_train(nn_base_arch,checkpoint,epocas,raw = False, prelu = False, high_dense = True)
#
# <ipython-input-40-763b347aa17f> in run_train(nn_base_arch, checkpoint, epocas, raw, prelu, high_dense)
#      16     checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
#      17     model.compile(loss='sparse_categorical_crossentropy', optimizer=optAMSGrad, metrics=['accuracy','mse'])
# ---> 18     history = model.fit(x_train, y_train,steps_per_epoch=(numTrainingSamples/(mbs*25)),epochs=epocas,validation_data=(valX, valY),callbacks=[checkpoint],batch_size = mbs)
#      19
#      20     return history
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1101               logs = tmp_logs  # No error, now safe to assign to logs.
#    1102               end_step = step + data_handler.step_increment
# -> 1103               callbacks.on_train_batch_end(end_step, logs)
#    1104         epoch_logs = copy.copy(logs)
#    1105
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     438     """
#     439     if self._should_call_train_batch_hooks:
# --> 440       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     441
#     442   def on_test_batch_begin(self, batch, logs=None):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     287       self._call_batch_begin_hook(mode, batch, logs)
#     288     elif hook == 'end':
# --> 289       self._call_batch_end_hook(mode, batch, logs)
#     290     else:
#     291       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     307       batch_time = time.time() - self._batch_start_time
#     308
# --> 309     self._call_batch_hook_helper(hook_name, batch, logs)
#     310
#     311     if self._check_timing:
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     340       hook = getattr(callback, hook_name)
#     341       if getattr(callback, '_supports_tf_logs', False):
# --> 342         hook(batch, logs)
#     343       else:
#     344         if numpy_logs is None:  # Only convert once.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     959
#     960   def on_train_batch_end(self, batch, logs=None):
# --> 961     self._batch_update_progbar(batch, logs)
#     962
#     963   def on_test_batch_end(self, batch, logs=None):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1014     if self.verbose == 1:
#    1015       # Only block async when verbose = 1.
# -> 1016       logs = tf_utils.to_numpy_or_python_type(logs)
#    1017       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1018
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     535     return t  # Don't turn ragged or sparse tensors to NumPy.
#     536
# --> 537   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     538
#     539
#
# KeyboardInterrupt:

# %%
model = history.model

# %%
model = history.model
model.load_weights(checkpoint)
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_11 (Sequential)   (None, 32)                24544
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 512)               16896
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               262656
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 3591
# =================================================================
# Total params: 309,735
# Trainable params: 308,711
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# ##Representación y evaluación de resultados

# %% [markdown]
# ### Representación

# %%
def plot_loss(history,epochs,name):
  print('\n\n')     
  plt.figure(figsize=(12,8))
  plt.plot(np.arange(0, epochs), history.history["loss"][0:epochs], label="train_loss")
  plt.plot(np.arange(0, epochs), history.history["val_loss"][0:epochs], label="val_loss")
  plt.plot(np.arange(0, epochs), history.history["accuracy"][0:epochs], label="train_acc")
  plt.plot(np.arange(0, epochs), history.history["val_accuracy"][0:epochs], label="val_acc")
  plt.title("Training Loss and Accuracy - {}".format(name))
  plt.xlabel("Epoch #")
  plt.ylabel("Loss/Accuracy")
  plt.legend()
  plt.show()

# %%
plot_loss(history,epocas,nn_base_arch+"PP_HH")

# %% [markdown]
# ### Evaluación con el subconjunto de test

# %%
test_eval = history.model.evaluate(x_test, y_test)
# Out:
# 110/110 [==============================] - 0s 4ms/step - loss: 0.2424 - accuracy: 0.9326 - mse: 12.2226
