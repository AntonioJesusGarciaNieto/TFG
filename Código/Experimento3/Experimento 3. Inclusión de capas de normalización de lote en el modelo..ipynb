# %% [markdown]
# # Experimento 3 : Inclusión de capas de normalización de lote en el modelo.

# %% [markdown]
# ## Librerías usadas.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math 
from glob import glob
from matplotlib import pyplot as plt
import os
from tqdm import tqdm
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import resample

# %%
import tensorflow as tf
gpus= tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ## Definición de rutas

# %%
#Rutas de los datos.
 
data_dir = os.path.dirname(os.path.realpath("../TFG/Datos/HAM10000_metadata.csv"))



csv_path = os.path.realpath(data_dir + "/HAM10000_metadata.csv")

#Variables globales

altura = 128
longitud = 128
clases = 7


print(data_dir)

print(csv_path)
# Out:
# /home/antgarnie/Escritorio/TFG/Datos
# /home/antgarnie/Escritorio/TFG/Datos/HAM10000_metadata.csv

# %% [markdown]
# ## Creación del marco de datos.

# %%
#Inicializando el dataFrame

dataFrame=pd.read_csv(csv_path)

#Mezclando carpetas.

all_image_path = glob(os.path.join(data_dir, '*', '*'))
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in all_image_path}

# Inicializando diccionario de categorías

lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

#Añadiendo columnas al dataFrame para que sea más legible.

dataFrame['path'] = dataFrame['image_id'].map(imageid_path_dict.get)
dataFrame['cell_type'] = dataFrame['dx'].map(lesion_type_dict.get) 
dataFrame['cell_type_idx'] = pd.Categorical(dataFrame['cell_type']).codes
dataFrame.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path          cell_type  \
# 0  /home/antgarnie/Escritorio/TFG/Datos/HAM10000_...  Benign keratosis
# 1  /home/antgarnie/Escritorio/TFG/Datos/HAM10000_...  Benign keratosis
# 2  /home/antgarnie/Escritorio/TFG/Datos/HAM10000_...  Benign keratosis
# 3  /home/antgarnie/Escritorio/TFG/Datos/HAM10000_...  Benign keratosis
# 4  /home/antgarnie/Escritorio/TFG/Datos/HAM10000_...  Benign keratosis
#
#    cell_type_idx
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2

# %% [markdown]
# ## Preparación de la red

# %%
def full_build_cnn_soco(withBatchNormalization = False, withDropout=False):
    
    model = tf.keras.Sequential()
    
    model.add(tf.keras.layers.Conv2D(32, (3,3),(1,1),input_shape=(altura,longitud,3)))
    model.add(tf.keras.layers.PReLU())
    if(withBatchNormalization):
        model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.Conv2D(32, (3,3),(1,1)))
    model.add(tf.keras.layers.PReLU())
    if(withBatchNormalization):
        model.add(tf.keras.layers.BatchNormalization())
    
    model.add(tf.keras.layers.MaxPooling2D((2,2)))

 
    model.add(tf.keras.layers.Conv2D(64, (3,3)))
    model.add(tf.keras.layers.PReLU())
    if(withBatchNormalization):
        model.add(tf.keras.layers.BatchNormalization())
        
    model.add(tf.keras.layers.MaxPooling2D((2,2)))
    
    model.add(tf.keras.layers.Flatten())
    
    model.add(tf.keras.layers.Dense(128))
    model.add(tf.keras.layers.PReLU())
    if(withDropout):
        model.add(tf.keras.layers.Dropout(0.5))

    model.add(tf.keras.layers.Dense(clases,activation='softmax'))

    return model

# %% [markdown]
# ## Se procede a crear un método que permita balancear la carga de imágenes

# %%
def balanced_dataset(df):
    df_balanced = pd.DataFrame()
    #df = pd.DataFrame()
    
    for cat in df['cell_type_idx'].unique():
        temp = resample(df[df['cell_type_idx'] == cat], 
                        replace=True,     # sample with replacement
                        n_samples=2500,   # to match majority class
                        random_state=123) # reproducible results

        # Combine majority class with upsampled minority class
        df_balanced = pd.concat([df_balanced, temp])
 
    df_balanced['cell_type'].value_counts()

    return df_balanced

def load_img_data(size, df, balanced=False):
    """
        ..
        first we should normalize the image from 0-255 to 0-1
    """
    
    img_h, img_w = size, size
    imgs = []
    
    if balanced:
        df = balanced_dataset(df)
    
    image_paths = list(df['path'])

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        img = img.astype(np.float32) / 255.
        #img = np.asarray(Image.open(image_paths[i]).resize((size,size)))
        imgs.append(img)

    imgs = np.stack(imgs, axis=0)
    print(imgs.shape)

    #imgs = imgs.astype(np.float32) / 255.
    
    return imgs, df['cell_type_idx'].values

# %% [markdown]
# ## Cargamos los datos y creamos los casos a experimentar.

# %%
def load_general_data():
    
    imgs, target = load_img_data(altura, dataFrame, balanced=True)
    
    x_train, x_transferLearning, y_train, y_transferLearning = train_test_split(imgs, target, test_size=0.60)
       
    source_data = [ x_transferLearning , y_transferLearning ]
    target_data = [ x_train , y_train ]
    
    x_train,x_test,y_train,y_test = train_test_split(target_data[0], target_data[1], test_size=0.70)
    
    train_data = [x_train,y_train]
    test_data = [x_test,y_test]
    
    return source_data,train_data,test_data


def get_data_for_ex(source_data,train_data,test_data):
    
    x_train = source_data[0]
    y_train = source_data[1]
    
    x_retrain = train_data[0]
    y_retrain = train_data[1]
    
    percent = math.floor(len(test_data[0])/100*30)
       
    x_validation = test_data[0][0:percent]
    y_validation = test_data[1][0:percent]
    
    
    x_test = test_data[0][percent:-1]
    y_test = test_data[1][percent:-1]
    
    return x_train,x_retrain,x_test,x_validation,y_train,y_retrain,y_test,y_validation


###############################################################################################################
# Definimos 7 experimentos cada uno con un optimizador distingo y definimos el número de iteraciones          #
###############################################################################################################

ITERATIONS_PER_EXP = 10
BATCH_SIZE = 16
EPOCHS = 15
LEARNING_RATE=0.0001

# %%
source_data,train_data,test_data = load_general_data()
x_train,x_retrain,x_test,x_validation,y_train,y_retrain,y_test,y_validation = get_data_for_ex(source_data,train_data,test_data)
# Out:
# 100%|██████████| 17500/17500 [01:52<00:00, 155.89it/s]
# (17500, 128, 128, 3)

# %%
def scheduler(epoch, lr):
    return 0.0001

#Experimento 1. Red con soco.
res11,res12,evaluations,evaluations1 = run_experiment(0,20)

#Experimento 2. Red con soco con BN y Dropout.
res21,res22,evaluations,evaluations2 = run_experiment(1,15)

#Experimento 3. Red con soco con BN y sin Dropout.
res31,res32,evaluations,evaluations3 = run_experiment(2,15)
# Out:
# Epoch 1/15
# 875/875 [==============================] - 49s 56ms/step - loss: 1.4938 - accuracy: 0.3994 - val_loss: 1.1787 - val_accuracy: 0.5571
# Epoch 2/15
# 875/875 [==============================] - 40s 46ms/step - loss: 1.0898 - accuracy: 0.5838 - val_loss: 0.8544 - val_accuracy: 0.6755
# Epoch 3/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.7781 - accuracy: 0.7087 - val_loss: 0.6521 - val_accuracy: 0.7524
# Epoch 4/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.5563 - accuracy: 0.7950 - val_loss: 0.4491 - val_accuracy: 0.8449
# Epoch 5/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.4081 - accuracy: 0.8503 - val_loss: 0.4656 - val_accuracy: 0.8449
# Epoch 6/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.3107 - accuracy: 0.8871 - val_loss: 0.4605 - val_accuracy: 0.8497
# Epoch 7/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.2634 - accuracy: 0.9026 - val_loss: 0.3896 - val_accuracy: 0.8585
# Epoch 8/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.2005 - accuracy: 0.9283 - val_loss: 0.3013 - val_accuracy: 0.9082
# Epoch 9/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.1843 - accuracy: 0.9325 - val_loss: 0.3120 - val_accuracy: 0.9034
# Epoch 10/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.1433 - accuracy: 0.9472 - val_loss: 0.3214 - val_accuracy: 0.9109
# Epoch 11/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.1210 - accuracy: 0.9566 - val_loss: 0.3256 - val_accuracy: 0.9177
# Epoch 12/15
# 875/875 [==============================] - 42s 47ms/step - loss: 0.1097 - accuracy: 0.9622 - val_loss: 0.3060 - val_accuracy: 0.9163
# Epoch 13/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.1200 - accuracy: 0.9572 - val_loss: 0.3016 - val_accuracy: 0.9163
# 3429
# 108/108 [==============================] - 3s 29ms/step - loss: 0.3263 - accuracy: 0.9172
# Epoch 1/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0823 - accuracy: 0.9707 - val_loss: 0.3001 - val_accuracy: 0.9272
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0740 - accuracy: 0.9733 - val_loss: 0.3177 - val_accuracy: 0.9231
# Epoch 3/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0739 - accuracy: 0.9739 - val_loss: 0.3179 - val_accuracy: 0.9265
# Epoch 4/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0746 - accuracy: 0.9725 - val_loss: 0.3163 - val_accuracy: 0.9293
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0716 - accuracy: 0.9751 - val_loss: 0.3184 - val_accuracy: 0.9299
# Epoch 6/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0681 - accuracy: 0.9749 - val_loss: 0.3274 - val_accuracy: 0.9245
# 108/108 [==============================] - 3s 29ms/step - loss: 0.3342 - accuracy: 0.9259
# ########################################################
# Iteración 1 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 41s 47ms/step - loss: 1.5653 - accuracy: 0.3651 - val_loss: 1.1946 - val_accuracy: 0.5524
# Epoch 2/15
# 875/875 [==============================] - 41s 47ms/step - loss: 1.1035 - accuracy: 0.5820 - val_loss: 0.8751 - val_accuracy: 0.6735
# Epoch 3/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.7556 - accuracy: 0.7181 - val_loss: 0.6163 - val_accuracy: 0.7755
# Epoch 4/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.5380 - accuracy: 0.8049 - val_loss: 0.4996 - val_accuracy: 0.8143
# Epoch 5/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.4088 - accuracy: 0.8513 - val_loss: 0.5235 - val_accuracy: 0.8143
# Epoch 6/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.3110 - accuracy: 0.8842 - val_loss: 0.3845 - val_accuracy: 0.8741
# Epoch 7/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.2374 - accuracy: 0.9164 - val_loss: 0.3730 - val_accuracy: 0.8946
# Epoch 8/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.2168 - accuracy: 0.9200 - val_loss: 0.2796 - val_accuracy: 0.9129
# Epoch 9/15
# 875/875 [==============================] - 41s 47ms/step - loss: 0.1667 - accuracy: 0.9400 - val_loss: 0.3230 - val_accuracy: 0.9129
# Epoch 10/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.1289 - accuracy: 0.9544 - val_loss: 0.2978 - val_accuracy: 0.9259
# Epoch 11/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.1294 - accuracy: 0.9533 - val_loss: 0.4359 - val_accuracy: 0.9061
# Epoch 12/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.1144 - accuracy: 0.9596 - val_loss: 0.3439 - val_accuracy: 0.9150
# Epoch 13/15
# 875/875 [==============================] - 41s 46ms/step - loss: 0.0931 - accuracy: 0.9672 - val_loss: 0.3610 - val_accuracy: 0.9136
# 3429
# 108/108 [==============================] - 3s 29ms/step - loss: 0.3849 - accuracy: 0.9146
# Epoch 1/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0752 - accuracy: 0.9764 - val_loss: 0.3513 - val_accuracy: 0.9170
# Epoch 2/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0610 - accuracy: 0.9782 - val_loss: 0.3657 - val_accuracy: 0.9197
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0630 - accuracy: 0.9775 - val_loss: 0.3641 - val_accuracy: 0.9204
# Epoch 4/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0643 - accuracy: 0.9780 - val_loss: 0.3477 - val_accuracy: 0.9279
# Epoch 5/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0641 - accuracy: 0.9769 - val_loss: 0.3622 - val_accuracy: 0.9252
# Epoch 6/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0595 - accuracy: 0.9786 - val_loss: 0.3793 - val_accuracy: 0.9211
# Epoch 7/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0614 - accuracy: 0.9781 - val_loss: 0.3766 - val_accuracy: 0.9231
# Epoch 8/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0609 - accuracy: 0.9790 - val_loss: 0.3930 - val_accuracy: 0.9224
# Epoch 9/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0574 - accuracy: 0.9789 - val_loss: 0.3801 - val_accuracy: 0.9231
# 108/108 [==============================] - 3s 28ms/step - loss: 0.4120 - accuracy: 0.9213
# ########################################################
# Iteración 2 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 40s 46ms/step - loss: 1.5149 - accuracy: 0.3770 - val_loss: 1.1986 - val_accuracy: 0.5150
# Epoch 2/15
# 875/875 [==============================] - 40s 46ms/step - loss: 1.1366 - accuracy: 0.5630 - val_loss: 0.9208 - val_accuracy: 0.6599
# Epoch 3/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.8420 - accuracy: 0.6873 - val_loss: 0.6726 - val_accuracy: 0.7320
# Epoch 4/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.6266 - accuracy: 0.7719 - val_loss: 0.4831 - val_accuracy: 0.8184
# Epoch 5/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.4742 - accuracy: 0.8235 - val_loss: 0.4873 - val_accuracy: 0.8197
# Epoch 6/15
# 875/875 [==============================] - 41s 46ms/step - loss: 0.3599 - accuracy: 0.8682 - val_loss: 0.3388 - val_accuracy: 0.8769
# Epoch 7/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.2868 - accuracy: 0.8939 - val_loss: 0.4005 - val_accuracy: 0.8694
# Epoch 8/15
# 875/875 [==============================] - 41s 46ms/step - loss: 0.2384 - accuracy: 0.9135 - val_loss: 0.2607 - val_accuracy: 0.9170
# Epoch 9/15
# 875/875 [==============================] - 41s 46ms/step - loss: 0.1911 - accuracy: 0.9308 - val_loss: 0.3089 - val_accuracy: 0.9095
# Epoch 10/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.1840 - accuracy: 0.9316 - val_loss: 0.2873 - val_accuracy: 0.9048
# Epoch 11/15
# 875/875 [==============================] - 41s 46ms/step - loss: 0.1438 - accuracy: 0.9456 - val_loss: 0.2743 - val_accuracy: 0.9238
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1196 - accuracy: 0.9578 - val_loss: 0.2661 - val_accuracy: 0.9245
# Epoch 13/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1026 - accuracy: 0.9620 - val_loss: 0.3017 - val_accuracy: 0.9190
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3109 - accuracy: 0.9236
# Epoch 1/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0777 - accuracy: 0.9724 - val_loss: 0.2760 - val_accuracy: 0.9333
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0720 - accuracy: 0.9744 - val_loss: 0.2702 - val_accuracy: 0.9327
# Epoch 3/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0682 - accuracy: 0.9771 - val_loss: 0.2666 - val_accuracy: 0.9340
# Epoch 4/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0635 - accuracy: 0.9768 - val_loss: 0.2777 - val_accuracy: 0.9333
# Epoch 5/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0645 - accuracy: 0.9775 - val_loss: 0.2741 - val_accuracy: 0.9354
# Epoch 6/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0616 - accuracy: 0.9771 - val_loss: 0.2755 - val_accuracy: 0.9340
# Epoch 7/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0653 - accuracy: 0.9763 - val_loss: 0.2777 - val_accuracy: 0.9347
# Epoch 8/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0616 - accuracy: 0.9768 - val_loss: 0.2754 - val_accuracy: 0.9340
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3472 - accuracy: 0.9274
# ########################################################
# Iteración 3 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.5996 - accuracy: 0.3419 - val_loss: 1.2223 - val_accuracy: 0.5048
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.1947 - accuracy: 0.5346 - val_loss: 0.9974 - val_accuracy: 0.6354
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.8929 - accuracy: 0.6639 - val_loss: 0.6999 - val_accuracy: 0.7531
# Epoch 4/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.6296 - accuracy: 0.7666 - val_loss: 0.5327 - val_accuracy: 0.8184
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.4382 - accuracy: 0.8418 - val_loss: 0.4512 - val_accuracy: 0.8422
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3427 - accuracy: 0.8760 - val_loss: 0.3561 - val_accuracy: 0.8782
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2630 - accuracy: 0.9060 - val_loss: 0.3587 - val_accuracy: 0.8939
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2114 - accuracy: 0.9253 - val_loss: 0.3577 - val_accuracy: 0.8925
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1703 - accuracy: 0.9395 - val_loss: 0.3488 - val_accuracy: 0.9048
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1431 - accuracy: 0.9476 - val_loss: 0.3263 - val_accuracy: 0.9177
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1266 - accuracy: 0.9544 - val_loss: 0.3392 - val_accuracy: 0.9170
# Epoch 12/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.0963 - accuracy: 0.9665 - val_loss: 0.3077 - val_accuracy: 0.9272
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0894 - accuracy: 0.9680 - val_loss: 0.2893 - val_accuracy: 0.9238
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1010 - accuracy: 0.9640 - val_loss: 0.3145 - val_accuracy: 0.9197
# Epoch 15/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0804 - accuracy: 0.9709 - val_loss: 0.3054 - val_accuracy: 0.9293
# 3429
# 108/108 [==============================] - 3s 28ms/step - loss: 0.3190 - accuracy: 0.9271
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0472 - accuracy: 0.9830 - val_loss: 0.3276 - val_accuracy: 0.9293
# Epoch 2/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0382 - accuracy: 0.9880 - val_loss: 0.3470 - val_accuracy: 0.9320
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0417 - accuracy: 0.9866 - val_loss: 0.3589 - val_accuracy: 0.9320
# Epoch 4/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0350 - accuracy: 0.9882 - val_loss: 0.3565 - val_accuracy: 0.9313
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0375 - accuracy: 0.9876 - val_loss: 0.3652 - val_accuracy: 0.9293
# Epoch 6/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.3656 - val_accuracy: 0.9340
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3853 - accuracy: 0.9294
# ########################################################
# Iteración 4 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 40s 45ms/step - loss: 1.5184 - accuracy: 0.3788 - val_loss: 1.2163 - val_accuracy: 0.4925
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.0991 - accuracy: 0.5790 - val_loss: 0.8377 - val_accuracy: 0.6748
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.7966 - accuracy: 0.7036 - val_loss: 0.6949 - val_accuracy: 0.7361
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5732 - accuracy: 0.7869 - val_loss: 0.4973 - val_accuracy: 0.8231
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.4346 - accuracy: 0.8412 - val_loss: 0.3932 - val_accuracy: 0.8673
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3349 - accuracy: 0.8776 - val_loss: 0.3571 - val_accuracy: 0.8735
# Epoch 7/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.2648 - accuracy: 0.9046 - val_loss: 0.3897 - val_accuracy: 0.8687
# Epoch 8/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.2207 - accuracy: 0.9219 - val_loss: 0.3282 - val_accuracy: 0.9000
# Epoch 9/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1923 - accuracy: 0.9308 - val_loss: 0.3074 - val_accuracy: 0.8986
# Epoch 10/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1593 - accuracy: 0.9416 - val_loss: 0.2769 - val_accuracy: 0.9122
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1313 - accuracy: 0.9555 - val_loss: 0.3692 - val_accuracy: 0.9150
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1323 - accuracy: 0.9528 - val_loss: 0.3526 - val_accuracy: 0.9068
# Epoch 13/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1107 - accuracy: 0.9577 - val_loss: 0.3389 - val_accuracy: 0.9190
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0850 - accuracy: 0.9697 - val_loss: 0.3287 - val_accuracy: 0.9333
# Epoch 15/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0792 - accuracy: 0.9726 - val_loss: 0.3790 - val_accuracy: 0.9177
# 3429
# 108/108 [==============================] - 3s 28ms/step - loss: 0.3960 - accuracy: 0.9172
# Epoch 1/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0624 - accuracy: 0.9787 - val_loss: 0.3521 - val_accuracy: 0.9306
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0568 - accuracy: 0.9816 - val_loss: 0.3571 - val_accuracy: 0.9347
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0575 - accuracy: 0.9809 - val_loss: 0.3883 - val_accuracy: 0.9279
# Epoch 4/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0550 - accuracy: 0.9813 - val_loss: 0.3673 - val_accuracy: 0.9320
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0509 - accuracy: 0.9835 - val_loss: 0.3888 - val_accuracy: 0.9279
# Epoch 6/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0502 - accuracy: 0.9825 - val_loss: 0.3793 - val_accuracy: 0.9313
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3809 - accuracy: 0.9312
# ########################################################
# Iteración 5 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.5334 - accuracy: 0.3778 - val_loss: 1.2539 - val_accuracy: 0.5184
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.1699 - accuracy: 0.5508 - val_loss: 0.9694 - val_accuracy: 0.6279
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.8962 - accuracy: 0.6625 - val_loss: 0.7533 - val_accuracy: 0.7170
# Epoch 4/15
# 875/875 [==============================] - 39s 44ms/step - loss: 0.6757 - accuracy: 0.7497 - val_loss: 0.5485 - val_accuracy: 0.8041
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5078 - accuracy: 0.8183 - val_loss: 0.5074 - val_accuracy: 0.8163
# Epoch 6/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.3987 - accuracy: 0.8566 - val_loss: 0.3948 - val_accuracy: 0.8605
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3123 - accuracy: 0.8837 - val_loss: 0.3393 - val_accuracy: 0.8755
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2481 - accuracy: 0.9085 - val_loss: 0.3229 - val_accuracy: 0.8905
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2144 - accuracy: 0.9215 - val_loss: 0.2766 - val_accuracy: 0.9061
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1941 - accuracy: 0.9295 - val_loss: 0.2558 - val_accuracy: 0.9095
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1553 - accuracy: 0.9451 - val_loss: 0.3038 - val_accuracy: 0.9075
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1422 - accuracy: 0.9477 - val_loss: 0.2720 - val_accuracy: 0.9218
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1226 - accuracy: 0.9547 - val_loss: 0.2357 - val_accuracy: 0.9231
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0988 - accuracy: 0.9651 - val_loss: 0.3147 - val_accuracy: 0.9197
# Epoch 15/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.0910 - accuracy: 0.9663 - val_loss: 0.2226 - val_accuracy: 0.9361
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.2678 - accuracy: 0.9332
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0501 - accuracy: 0.9822 - val_loss: 0.2450 - val_accuracy: 0.9422
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.2618 - val_accuracy: 0.9340
# Epoch 3/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0448 - accuracy: 0.9839 - val_loss: 0.2687 - val_accuracy: 0.9367
# Epoch 4/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0437 - accuracy: 0.9841 - val_loss: 0.2724 - val_accuracy: 0.9381
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0415 - accuracy: 0.9870 - val_loss: 0.3017 - val_accuracy: 0.9320
# Epoch 6/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0411 - accuracy: 0.9858 - val_loss: 0.2876 - val_accuracy: 0.9354
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3472 - accuracy: 0.9321
# ########################################################
# Iteración 6 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.5080 - accuracy: 0.3927 - val_loss: 1.2162 - val_accuracy: 0.5082
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.0931 - accuracy: 0.5837 - val_loss: 1.0186 - val_accuracy: 0.5884
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.7975 - accuracy: 0.7071 - val_loss: 0.6549 - val_accuracy: 0.7714
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5766 - accuracy: 0.7893 - val_loss: 0.5136 - val_accuracy: 0.8190
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.4481 - accuracy: 0.8339 - val_loss: 0.4417 - val_accuracy: 0.8442
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3486 - accuracy: 0.8697 - val_loss: 0.4426 - val_accuracy: 0.8551
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2767 - accuracy: 0.9010 - val_loss: 0.3705 - val_accuracy: 0.8810
# Epoch 8/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.2324 - accuracy: 0.9164 - val_loss: 0.3060 - val_accuracy: 0.8993
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1790 - accuracy: 0.9340 - val_loss: 0.3418 - val_accuracy: 0.8980
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1615 - accuracy: 0.9417 - val_loss: 0.2927 - val_accuracy: 0.9109
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1421 - accuracy: 0.9473 - val_loss: 0.3085 - val_accuracy: 0.9109
# Epoch 12/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1261 - accuracy: 0.9535 - val_loss: 0.3273 - val_accuracy: 0.9156
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1130 - accuracy: 0.9610 - val_loss: 0.4242 - val_accuracy: 0.9075
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1172 - accuracy: 0.9587 - val_loss: 0.3264 - val_accuracy: 0.9143
# Epoch 15/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0866 - accuracy: 0.9694 - val_loss: 0.4097 - val_accuracy: 0.9163
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4004 - accuracy: 0.9189
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0679 - accuracy: 0.9766 - val_loss: 0.3847 - val_accuracy: 0.9259
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0613 - accuracy: 0.9789 - val_loss: 0.3872 - val_accuracy: 0.9252
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0584 - accuracy: 0.9787 - val_loss: 0.3847 - val_accuracy: 0.9231
# Epoch 4/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0576 - accuracy: 0.9810 - val_loss: 0.3826 - val_accuracy: 0.9238
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0559 - accuracy: 0.9804 - val_loss: 0.3865 - val_accuracy: 0.9286
# Epoch 6/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0545 - accuracy: 0.9818 - val_loss: 0.3928 - val_accuracy: 0.9252
# Epoch 7/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0581 - accuracy: 0.9802 - val_loss: 0.3892 - val_accuracy: 0.9259
# Epoch 8/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0550 - accuracy: 0.9802 - val_loss: 0.3910 - val_accuracy: 0.9252
# Epoch 9/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0518 - accuracy: 0.9817 - val_loss: 0.3900 - val_accuracy: 0.9265
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3758 - accuracy: 0.9274
# ########################################################
# Iteración 7 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.5538 - accuracy: 0.3641 - val_loss: 1.2584 - val_accuracy: 0.5136
# Epoch 2/15
# 875/875 [==============================] - 40s 45ms/step - loss: 1.1581 - accuracy: 0.5512 - val_loss: 1.0447 - val_accuracy: 0.6048
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.8425 - accuracy: 0.6810 - val_loss: 0.6782 - val_accuracy: 0.7524
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.6041 - accuracy: 0.7782 - val_loss: 0.5910 - val_accuracy: 0.7816
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.4404 - accuracy: 0.8394 - val_loss: 0.4293 - val_accuracy: 0.8483
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3528 - accuracy: 0.8693 - val_loss: 0.4323 - val_accuracy: 0.8531
# Epoch 7/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.2748 - accuracy: 0.9012 - val_loss: 0.3385 - val_accuracy: 0.8939
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2098 - accuracy: 0.9233 - val_loss: 0.2878 - val_accuracy: 0.9170
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1853 - accuracy: 0.9309 - val_loss: 0.3177 - val_accuracy: 0.9075
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1516 - accuracy: 0.9460 - val_loss: 0.2983 - val_accuracy: 0.9265
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1375 - accuracy: 0.9501 - val_loss: 0.3293 - val_accuracy: 0.9143
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1259 - accuracy: 0.9539 - val_loss: 0.3587 - val_accuracy: 0.9163
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1197 - accuracy: 0.9572 - val_loss: 0.3793 - val_accuracy: 0.9184
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3503 - accuracy: 0.9186
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0668 - accuracy: 0.9772 - val_loss: 0.3631 - val_accuracy: 0.9259
# Epoch 2/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0538 - accuracy: 0.9813 - val_loss: 0.3874 - val_accuracy: 0.9245
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0556 - accuracy: 0.9816 - val_loss: 0.3797 - val_accuracy: 0.9259
# Epoch 4/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0521 - accuracy: 0.9811 - val_loss: 0.3885 - val_accuracy: 0.9265
# Epoch 5/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0516 - accuracy: 0.9812 - val_loss: 0.3988 - val_accuracy: 0.9259
# Epoch 6/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0524 - accuracy: 0.9820 - val_loss: 0.3963 - val_accuracy: 0.9299
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3689 - accuracy: 0.9297
# ########################################################
# Iteración 8 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.5708 - accuracy: 0.3548 - val_loss: 1.3027 - val_accuracy: 0.4605
# Epoch 2/15
# 875/875 [==============================] - 40s 45ms/step - loss: 1.2027 - accuracy: 0.5295 - val_loss: 0.9823 - val_accuracy: 0.6204
# Epoch 3/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.9112 - accuracy: 0.6540 - val_loss: 0.7703 - val_accuracy: 0.7014
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.6742 - accuracy: 0.7477 - val_loss: 0.5686 - val_accuracy: 0.7939
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.4987 - accuracy: 0.8170 - val_loss: 0.5155 - val_accuracy: 0.8170
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3808 - accuracy: 0.8606 - val_loss: 0.3867 - val_accuracy: 0.8803
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2985 - accuracy: 0.8895 - val_loss: 0.4962 - val_accuracy: 0.8497
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2351 - accuracy: 0.9140 - val_loss: 0.3225 - val_accuracy: 0.9048
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2042 - accuracy: 0.9272 - val_loss: 0.3128 - val_accuracy: 0.9136
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1687 - accuracy: 0.9398 - val_loss: 0.3006 - val_accuracy: 0.9150
# Epoch 11/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1386 - accuracy: 0.9505 - val_loss: 0.3780 - val_accuracy: 0.8952
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1353 - accuracy: 0.9523 - val_loss: 0.3566 - val_accuracy: 0.9204
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1155 - accuracy: 0.9589 - val_loss: 0.3713 - val_accuracy: 0.9116
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0929 - accuracy: 0.9652 - val_loss: 0.3588 - val_accuracy: 0.9252
# Epoch 15/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0834 - accuracy: 0.9706 - val_loss: 0.3701 - val_accuracy: 0.9252
# 3429
# 108/108 [==============================] - 3s 28ms/step - loss: 0.3647 - accuracy: 0.9216
# Epoch 1/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0529 - accuracy: 0.9815 - val_loss: 0.3485 - val_accuracy: 0.9374
# Epoch 2/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0452 - accuracy: 0.9847 - val_loss: 0.3553 - val_accuracy: 0.9408
# Epoch 3/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.3584 - val_accuracy: 0.9388
# Epoch 4/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0392 - accuracy: 0.9857 - val_loss: 0.3695 - val_accuracy: 0.9395
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0425 - accuracy: 0.9855 - val_loss: 0.3752 - val_accuracy: 0.9401
# Epoch 6/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0373 - accuracy: 0.9870 - val_loss: 0.3767 - val_accuracy: 0.9395
# 108/108 [==============================] - 3s 28ms/step - loss: 0.3972 - accuracy: 0.9297
# ########################################################
# Iteración 9 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 40s 45ms/step - loss: 1.5372 - accuracy: 0.3695 - val_loss: 1.2537 - val_accuracy: 0.5048
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.1550 - accuracy: 0.5493 - val_loss: 0.9787 - val_accuracy: 0.6395
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.9066 - accuracy: 0.6604 - val_loss: 0.7901 - val_accuracy: 0.7007
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.6893 - accuracy: 0.7436 - val_loss: 0.5923 - val_accuracy: 0.7796
# Epoch 5/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.5075 - accuracy: 0.8156 - val_loss: 0.6250 - val_accuracy: 0.7816
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3867 - accuracy: 0.8608 - val_loss: 0.4305 - val_accuracy: 0.8497
# Epoch 7/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.2957 - accuracy: 0.8905 - val_loss: 0.3454 - val_accuracy: 0.8776
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2463 - accuracy: 0.9118 - val_loss: 0.3784 - val_accuracy: 0.8871
# Epoch 9/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1958 - accuracy: 0.9314 - val_loss: 0.3537 - val_accuracy: 0.8966
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1827 - accuracy: 0.9321 - val_loss: 0.3418 - val_accuracy: 0.9109
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1630 - accuracy: 0.9429 - val_loss: 0.3356 - val_accuracy: 0.9109
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1333 - accuracy: 0.9559 - val_loss: 0.3278 - val_accuracy: 0.9150
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1187 - accuracy: 0.9561 - val_loss: 0.3542 - val_accuracy: 0.9184
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1040 - accuracy: 0.9626 - val_loss: 0.3024 - val_accuracy: 0.9299
# Epoch 15/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0831 - accuracy: 0.9690 - val_loss: 0.3854 - val_accuracy: 0.9163
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3576 - accuracy: 0.9189
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0762 - accuracy: 0.9726 - val_loss: 0.3469 - val_accuracy: 0.9224
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0599 - accuracy: 0.9809 - val_loss: 0.3467 - val_accuracy: 0.9224
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0565 - accuracy: 0.9810 - val_loss: 0.3550 - val_accuracy: 0.9231
# Epoch 4/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0558 - accuracy: 0.9814 - val_loss: 0.3627 - val_accuracy: 0.9231
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0599 - accuracy: 0.9791 - val_loss: 0.3749 - val_accuracy: 0.9224
# Epoch 6/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0584 - accuracy: 0.9798 - val_loss: 0.3655 - val_accuracy: 0.9259
# Epoch 7/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0561 - accuracy: 0.9796 - val_loss: 0.3746 - val_accuracy: 0.9245
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3612 - accuracy: 0.9367
# ########################################################
# Iteración 10 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 49s 56ms/step - loss: 1.6933 - accuracy: 0.4165 - val_loss: 1.0868 - val_accuracy: 0.5823
# Epoch 2/15
# 875/875 [==============================] - 49s 56ms/step - loss: 1.1094 - accuracy: 0.5802 - val_loss: 0.8266 - val_accuracy: 0.6844
# Epoch 3/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.7973 - accuracy: 0.6989 - val_loss: 0.6336 - val_accuracy: 0.7497
# Epoch 4/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.5973 - accuracy: 0.7760 - val_loss: 1.9154 - val_accuracy: 0.4667
# Epoch 5/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.4612 - accuracy: 0.8295 - val_loss: 0.3814 - val_accuracy: 0.8544
# Epoch 6/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.3707 - accuracy: 0.8633 - val_loss: 0.6303 - val_accuracy: 0.7626
# Epoch 7/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.3108 - accuracy: 0.8865 - val_loss: 0.4325 - val_accuracy: 0.8476
# Epoch 8/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.2466 - accuracy: 0.9066 - val_loss: 0.3965 - val_accuracy: 0.8687
# Epoch 9/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.2215 - accuracy: 0.9197 - val_loss: 1.0183 - val_accuracy: 0.6517
# Epoch 10/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1797 - accuracy: 0.9360 - val_loss: 0.4485 - val_accuracy: 0.8279
# 3429
# 108/108 [==============================] - 3s 30ms/step - loss: 0.4200 - accuracy: 0.8422
# Epoch 1/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.2521 - accuracy: 0.9054 - val_loss: 0.3114 - val_accuracy: 0.8973
# Epoch 2/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2299 - accuracy: 0.9141 - val_loss: 0.3072 - val_accuracy: 0.9007
# Epoch 3/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2078 - accuracy: 0.9235 - val_loss: 0.3022 - val_accuracy: 0.8980
# Epoch 4/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2035 - accuracy: 0.9256 - val_loss: 0.3040 - val_accuracy: 0.9020
# Epoch 5/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2083 - accuracy: 0.9206 - val_loss: 0.3017 - val_accuracy: 0.9034
# Epoch 6/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2039 - accuracy: 0.9245 - val_loss: 0.3085 - val_accuracy: 0.9007
# Epoch 7/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.2085 - accuracy: 0.9203 - val_loss: 0.3109 - val_accuracy: 0.9041
# Epoch 8/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2087 - accuracy: 0.9215 - val_loss: 0.3092 - val_accuracy: 0.9048
# Epoch 9/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.2075 - accuracy: 0.9225 - val_loss: 0.3040 - val_accuracy: 0.9048
# Epoch 10/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.2042 - accuracy: 0.9236 - val_loss: 0.3139 - val_accuracy: 0.8959
# 108/108 [==============================] - 3s 30ms/step - loss: 0.2988 - accuracy: 0.9102
# ########################################################
# Iteración 1 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 49s 56ms/step - loss: 1.7134 - accuracy: 0.3903 - val_loss: 1.2028 - val_accuracy: 0.5143
# Epoch 2/15
# 875/875 [==============================] - 50s 57ms/step - loss: 1.1536 - accuracy: 0.5769 - val_loss: 0.9380 - val_accuracy: 0.6306
# Epoch 3/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.8580 - accuracy: 0.6829 - val_loss: 2.4042 - val_accuracy: 0.3116
# Epoch 4/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.6285 - accuracy: 0.7638 - val_loss: 0.8220 - val_accuracy: 0.7007
# Epoch 5/15
# 875/875 [==============================] - 50s 57ms/step - loss: 0.4816 - accuracy: 0.8203 - val_loss: 0.4745 - val_accuracy: 0.8143
# Epoch 6/15
# 875/875 [==============================] - 50s 57ms/step - loss: 0.3650 - accuracy: 0.8630 - val_loss: 0.6330 - val_accuracy: 0.7639
# Epoch 7/15
# 875/875 [==============================] - 49s 57ms/step - loss: 0.3047 - accuracy: 0.8901 - val_loss: 0.3667 - val_accuracy: 0.8694
# Epoch 8/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.2566 - accuracy: 0.9065 - val_loss: 0.3842 - val_accuracy: 0.8741
# Epoch 9/15
# 875/875 [==============================] - 49s 57ms/step - loss: 0.2140 - accuracy: 0.9220 - val_loss: 0.4165 - val_accuracy: 0.8633
# Epoch 10/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1827 - accuracy: 0.9352 - val_loss: 0.2666 - val_accuracy: 0.9116
# Epoch 11/15
# 875/875 [==============================] - 49s 57ms/step - loss: 0.1614 - accuracy: 0.9416 - val_loss: 0.3183 - val_accuracy: 0.9034
# Epoch 12/15
# 875/875 [==============================] - 49s 57ms/step - loss: 0.1242 - accuracy: 0.9566 - val_loss: 0.3379 - val_accuracy: 0.8864
# Epoch 13/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1126 - accuracy: 0.9595 - val_loss: 0.3153 - val_accuracy: 0.9163
# Epoch 14/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.0942 - accuracy: 0.9686 - val_loss: 0.2561 - val_accuracy: 0.9354
# Epoch 15/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.0889 - accuracy: 0.9673 - val_loss: 0.3307 - val_accuracy: 0.9129
# 3429
# 108/108 [==============================] - 3s 30ms/step - loss: 0.3898 - accuracy: 0.9093
# Epoch 1/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.1168 - accuracy: 0.9592 - val_loss: 0.2811 - val_accuracy: 0.9286
# Epoch 2/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1121 - accuracy: 0.9596 - val_loss: 0.2724 - val_accuracy: 0.9320
# Epoch 3/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1008 - accuracy: 0.9649 - val_loss: 0.2818 - val_accuracy: 0.9293
# Epoch 4/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0994 - accuracy: 0.9651 - val_loss: 0.2733 - val_accuracy: 0.9333
# Epoch 5/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0983 - accuracy: 0.9662 - val_loss: 0.2827 - val_accuracy: 0.9299
# Epoch 6/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0987 - accuracy: 0.9647 - val_loss: 0.2836 - val_accuracy: 0.9354
# Epoch 7/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.0990 - accuracy: 0.9647 - val_loss: 0.2780 - val_accuracy: 0.9320
# 108/108 [==============================] - 3s 30ms/step - loss: 0.3180 - accuracy: 0.9253
# ########################################################
# Iteración 2 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 50s 57ms/step - loss: 1.7092 - accuracy: 0.3960 - val_loss: 1.3372 - val_accuracy: 0.4823
# Epoch 2/15
# 875/875 [==============================] - 49s 57ms/step - loss: 1.1560 - accuracy: 0.5692 - val_loss: 1.0152 - val_accuracy: 0.6027
# Epoch 3/15
# 875/875 [==============================] - 50s 57ms/step - loss: 0.8476 - accuracy: 0.6877 - val_loss: 0.7994 - val_accuracy: 0.7150
# Epoch 4/15
# 875/875 [==============================] - 49s 57ms/step - loss: 0.6384 - accuracy: 0.7634 - val_loss: 0.7198 - val_accuracy: 0.7136
# Epoch 5/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.4800 - accuracy: 0.8280 - val_loss: 0.5971 - val_accuracy: 0.7864
# Epoch 6/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.3780 - accuracy: 0.8618 - val_loss: 0.3243 - val_accuracy: 0.8789
# Epoch 7/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.3231 - accuracy: 0.8820 - val_loss: 0.4087 - val_accuracy: 0.8463
# Epoch 8/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.2444 - accuracy: 0.9113 - val_loss: 0.3505 - val_accuracy: 0.8959
# Epoch 9/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.2010 - accuracy: 0.9298 - val_loss: 0.3174 - val_accuracy: 0.8932
# Epoch 10/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1829 - accuracy: 0.9332 - val_loss: 0.6092 - val_accuracy: 0.8048
# Epoch 11/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1617 - accuracy: 0.9401 - val_loss: 0.2580 - val_accuracy: 0.9170
# Epoch 12/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1244 - accuracy: 0.9545 - val_loss: 0.3480 - val_accuracy: 0.8905
# Epoch 13/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1109 - accuracy: 0.9613 - val_loss: 0.2437 - val_accuracy: 0.9340
# Epoch 14/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.0889 - accuracy: 0.9699 - val_loss: 0.2974 - val_accuracy: 0.9272
# Epoch 15/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.0941 - accuracy: 0.9676 - val_loss: 0.4014 - val_accuracy: 0.8721
# 3429
# 108/108 [==============================] - 3s 30ms/step - loss: 0.4297 - accuracy: 0.8594
# Epoch 1/15
# 875/875 [==============================] - 15s 17ms/step - loss: 0.1762 - accuracy: 0.9408 - val_loss: 0.2684 - val_accuracy: 0.9184
# Epoch 2/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.1440 - accuracy: 0.9484 - val_loss: 0.2533 - val_accuracy: 0.9238
# Epoch 3/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1346 - accuracy: 0.9513 - val_loss: 0.2648 - val_accuracy: 0.9272
# Epoch 4/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1344 - accuracy: 0.9520 - val_loss: 0.2629 - val_accuracy: 0.9327
# Epoch 5/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1318 - accuracy: 0.9512 - val_loss: 0.2659 - val_accuracy: 0.9293
# Epoch 6/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.1263 - accuracy: 0.9556 - val_loss: 0.2650 - val_accuracy: 0.9306
# Epoch 7/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.1303 - accuracy: 0.9559 - val_loss: 0.2653 - val_accuracy: 0.9286
# 108/108 [==============================] - 3s 30ms/step - loss: 0.2763 - accuracy: 0.9233
# ########################################################
# Iteración 3 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 49s 56ms/step - loss: 1.6596 - accuracy: 0.4065 - val_loss: 1.2868 - val_accuracy: 0.5211
# Epoch 2/15
# 875/875 [==============================] - 50s 57ms/step - loss: 1.1063 - accuracy: 0.5880 - val_loss: 0.7789 - val_accuracy: 0.7279
# Epoch 3/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.7891 - accuracy: 0.7053 - val_loss: 0.6977 - val_accuracy: 0.7381
# Epoch 4/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.5891 - accuracy: 0.7824 - val_loss: 0.6289 - val_accuracy: 0.7816
# Epoch 5/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.4784 - accuracy: 0.8246 - val_loss: 0.4916 - val_accuracy: 0.8293
# Epoch 6/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.3692 - accuracy: 0.8643 - val_loss: 0.4363 - val_accuracy: 0.8422
# Epoch 7/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.2881 - accuracy: 0.8957 - val_loss: 0.3247 - val_accuracy: 0.8932
# Epoch 8/15
# 875/875 [==============================] - 50s 57ms/step - loss: 0.2536 - accuracy: 0.9078 - val_loss: 0.5192 - val_accuracy: 0.8279
# Epoch 9/15
# 875/875 [==============================] - 50s 57ms/step - loss: 0.2021 - accuracy: 0.9288 - val_loss: 0.3238 - val_accuracy: 0.9007
# Epoch 10/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1745 - accuracy: 0.9357 - val_loss: 0.5367 - val_accuracy: 0.8374
# Epoch 11/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1511 - accuracy: 0.9441 - val_loss: 0.2646 - val_accuracy: 0.9136
# Epoch 12/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1268 - accuracy: 0.9551 - val_loss: 0.2520 - val_accuracy: 0.9252
# Epoch 13/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.1102 - accuracy: 0.9598 - val_loss: 0.3022 - val_accuracy: 0.9204
# Epoch 14/15
# 875/875 [==============================] - 50s 57ms/step - loss: 0.0962 - accuracy: 0.9665 - val_loss: 0.3112 - val_accuracy: 0.9286
# Epoch 15/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.0957 - accuracy: 0.9683 - val_loss: 0.8669 - val_accuracy: 0.7932
# 3429
# 108/108 [==============================] - 3s 30ms/step - loss: 0.8582 - accuracy: 0.7897
# Epoch 1/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2823 - accuracy: 0.9097 - val_loss: 0.3622 - val_accuracy: 0.9020
# Epoch 2/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.2073 - accuracy: 0.9303 - val_loss: 0.3504 - val_accuracy: 0.9102
# Epoch 3/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.2046 - accuracy: 0.9296 - val_loss: 0.3545 - val_accuracy: 0.9102
# Epoch 4/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1961 - accuracy: 0.9310 - val_loss: 0.3402 - val_accuracy: 0.9116
# Epoch 5/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.1912 - accuracy: 0.9354 - val_loss: 0.3560 - val_accuracy: 0.9068
# Epoch 6/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.1940 - accuracy: 0.9314 - val_loss: 0.3529 - val_accuracy: 0.9109
# Epoch 7/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.1953 - accuracy: 0.9324 - val_loss: 0.3601 - val_accuracy: 0.9095
# Epoch 8/15
# 875/875 [==============================] - 13s 14ms/step - loss: 0.1986 - accuracy: 0.9330 - val_loss: 0.3583 - val_accuracy: 0.9122
# Epoch 9/15
# 875/875 [==============================] - 14s 16ms/step - loss: 0.1966 - accuracy: 0.9307 - val_loss: 0.3475 - val_accuracy: 0.9177
# 108/108 [==============================] - 3s 30ms/step - loss: 0.3172 - accuracy: 0.9160
# ########################################################
# Iteración 4 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 50s 57ms/step - loss: 1.6960 - accuracy: 0.3934 - val_loss: 1.6443 - val_accuracy: 0.4449
# Epoch 2/15
# 875/875 [==============================] - 50s 57ms/step - loss: 1.2367 - accuracy: 0.5368 - val_loss: 1.0219 - val_accuracy: 0.6122
# Epoch 3/15
# 875/875 [==============================] - 49s 56ms/step - loss: 0.9031 - accuracy: 0.6587 - val_loss: 1.0465 - val_accuracy: 0.5898
# ...
# Epoch 4/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.4497 - val_accuracy: 0.9109
# Epoch 5/15
# 875/875 [==============================] - 11s 12ms/step - loss: 0.0264 - accuracy: 0.9924 - val_loss: 0.4451 - val_accuracy: 0.9129
# Epoch 6/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0255 - accuracy: 0.9928 - val_loss: 0.4620 - val_accuracy: 0.9095
# Epoch 7/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0235 - accuracy: 0.9930 - val_loss: 0.4582 - val_accuracy: 0.9116
# 108/108 [==============================] - 3s 28ms/step - loss: 0.4087 - accuracy: 0.9242
# ########################################################
# Iteración 5 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 40s 46ms/step - loss: 1.4564 - accuracy: 0.4171 - val_loss: 1.1733 - val_accuracy: 0.5395
# Epoch 2/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.9106 - accuracy: 0.6592 - val_loss: 0.6366 - val_accuracy: 0.7694
# Epoch 3/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.5333 - accuracy: 0.8053 - val_loss: 0.4798 - val_accuracy: 0.8211
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3077 - accuracy: 0.8882 - val_loss: 0.4774 - val_accuracy: 0.8408
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1870 - accuracy: 0.9355 - val_loss: 0.3028 - val_accuracy: 0.8980
# Epoch 6/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.1211 - accuracy: 0.9587 - val_loss: 0.3722 - val_accuracy: 0.8796
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0798 - accuracy: 0.9710 - val_loss: 0.3244 - val_accuracy: 0.9075
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0588 - accuracy: 0.9789 - val_loss: 0.4415 - val_accuracy: 0.8932
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0538 - accuracy: 0.9831 - val_loss: 0.3413 - val_accuracy: 0.9272
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0433 - accuracy: 0.9863 - val_loss: 0.3950 - val_accuracy: 0.9231
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3723 - accuracy: 0.9218
# Epoch 1/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.3835 - val_accuracy: 0.9313
# Epoch 2/15
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.3664 - val_accuracy: 0.9381
# Epoch 3/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.4012 - val_accuracy: 0.9361
# Epoch 4/15
# 875/875 [==============================] - 13s 15ms/step - loss: 0.0033 - accuracy: 0.9999 - val_loss: 0.4114 - val_accuracy: 0.9340
# Epoch 5/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.4095 - val_accuracy: 0.9374
# Epoch 6/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.4446 - val_accuracy: 0.9333
# Epoch 7/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4405 - val_accuracy: 0.9347
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4222 - accuracy: 0.9329
# ########################################################
# Iteración 6 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 40s 45ms/step - loss: 1.4535 - accuracy: 0.4208 - val_loss: 1.1495 - val_accuracy: 0.5497
# Epoch 2/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.9248 - accuracy: 0.6516 - val_loss: 0.8554 - val_accuracy: 0.6796
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5857 - accuracy: 0.7877 - val_loss: 0.5869 - val_accuracy: 0.7667
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3653 - accuracy: 0.8697 - val_loss: 0.4343 - val_accuracy: 0.8401
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2387 - accuracy: 0.9135 - val_loss: 0.4093 - val_accuracy: 0.8680
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1694 - accuracy: 0.9383 - val_loss: 0.3892 - val_accuracy: 0.8905
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1030 - accuracy: 0.9635 - val_loss: 0.3715 - val_accuracy: 0.9034
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0760 - accuracy: 0.9751 - val_loss: 0.3354 - val_accuracy: 0.9122
# Epoch 9/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.0421 - accuracy: 0.9865 - val_loss: 0.3626 - val_accuracy: 0.9156
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0776 - accuracy: 0.9746 - val_loss: 0.4318 - val_accuracy: 0.9034
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0855 - accuracy: 0.9712 - val_loss: 0.3915 - val_accuracy: 0.9231
# Epoch 12/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.0162 - accuracy: 0.9954 - val_loss: 0.3925 - val_accuracy: 0.9238
# Epoch 13/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.4491 - val_accuracy: 0.9313
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4865 - accuracy: 0.9265
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.4078 - val_accuracy: 0.9354
# Epoch 2/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4182 - val_accuracy: 0.9361
# Epoch 3/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.9374
# Epoch 4/15
# 875/875 [==============================] - 13s 14ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4323 - val_accuracy: 0.9367
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 8.2691e-04 - accuracy: 1.0000 - val_loss: 0.4399 - val_accuracy: 0.9354
# Epoch 6/15
# 875/875 [==============================] - 12s 13ms/step - loss: 7.4965e-04 - accuracy: 1.0000 - val_loss: 0.4432 - val_accuracy: 0.9354
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4825 - accuracy: 0.9338
# ########################################################
# Iteración 7 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 40s 45ms/step - loss: 1.3423 - accuracy: 0.4734 - val_loss: 1.2268 - val_accuracy: 0.5245
# Epoch 2/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.8624 - accuracy: 0.6723 - val_loss: 0.9809 - val_accuracy: 0.6340
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5253 - accuracy: 0.8109 - val_loss: 0.4758 - val_accuracy: 0.8340
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3303 - accuracy: 0.8851 - val_loss: 0.3825 - val_accuracy: 0.8762
# Epoch 5/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.2051 - accuracy: 0.9291 - val_loss: 0.3306 - val_accuracy: 0.8959
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1451 - accuracy: 0.9475 - val_loss: 0.3471 - val_accuracy: 0.9054
# Epoch 7/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.0902 - accuracy: 0.9672 - val_loss: 0.3271 - val_accuracy: 0.9224
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0644 - accuracy: 0.9776 - val_loss: 0.3320 - val_accuracy: 0.9184
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0632 - accuracy: 0.9787 - val_loss: 0.5843 - val_accuracy: 0.8714
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.4140 - val_accuracy: 0.9204
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.4327 - val_accuracy: 0.9245
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.4622 - val_accuracy: 0.9272
# 3429
# 108/108 [==============================] - 3s 28ms/step - loss: 0.4134 - accuracy: 0.9335
# Epoch 1/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.4427 - val_accuracy: 0.9320
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.4729 - val_accuracy: 0.9313
# Epoch 3/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.4860 - val_accuracy: 0.9313
# Epoch 4/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4796 - val_accuracy: 0.9306
# Epoch 5/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4971 - val_accuracy: 0.9306
# Epoch 6/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5056 - val_accuracy: 0.9306
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4619 - accuracy: 0.9335
# ########################################################
# Iteración 8 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.4446 - accuracy: 0.4220 - val_loss: 1.1901 - val_accuracy: 0.5415
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.8536 - accuracy: 0.6828 - val_loss: 0.7346 - val_accuracy: 0.7272
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5064 - accuracy: 0.8139 - val_loss: 0.5369 - val_accuracy: 0.8034
# Epoch 4/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.3198 - accuracy: 0.8846 - val_loss: 0.4495 - val_accuracy: 0.8565
# Epoch 5/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.2069 - accuracy: 0.9285 - val_loss: 0.4318 - val_accuracy: 0.8782
# Epoch 6/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1225 - accuracy: 0.9569 - val_loss: 0.3692 - val_accuracy: 0.9061
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0793 - accuracy: 0.9713 - val_loss: 0.3516 - val_accuracy: 0.9211
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0513 - accuracy: 0.9826 - val_loss: 0.4520 - val_accuracy: 0.9020
# Epoch 9/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0518 - accuracy: 0.9823 - val_loss: 0.4722 - val_accuracy: 0.9082
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0326 - accuracy: 0.9900 - val_loss: 0.5017 - val_accuracy: 0.8959
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0498 - accuracy: 0.9862 - val_loss: 0.3513 - val_accuracy: 0.9347
# Epoch 12/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.4306 - val_accuracy: 0.9333
# Epoch 13/15
# 875/875 [==============================] - 39s 45ms/step - loss: 7.6430e-04 - accuracy: 1.0000 - val_loss: 0.4665 - val_accuracy: 0.9293
# Epoch 14/15
# 875/875 [==============================] - 39s 45ms/step - loss: 3.8822e-04 - accuracy: 1.0000 - val_loss: 0.4728 - val_accuracy: 0.9327
# Epoch 15/15
# 875/875 [==============================] - 39s 45ms/step - loss: 2.6169e-04 - accuracy: 1.0000 - val_loss: 0.4823 - val_accuracy: 0.9333
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.4380 - accuracy: 0.9326
# Epoch 1/15
# 875/875 [==============================] - 12s 14ms/step - loss: 1.3448e-04 - accuracy: 1.0000 - val_loss: 0.6141 - val_accuracy: 0.9265
# Epoch 2/15
# 875/875 [==============================] - 13s 15ms/step - loss: 2.7129e-04 - accuracy: 0.9999 - val_loss: 0.6314 - val_accuracy: 0.9299
# Epoch 3/15
# 875/875 [==============================] - 12s 14ms/step - loss: 3.6570e-05 - accuracy: 1.0000 - val_loss: 0.6423 - val_accuracy: 0.9272
# Epoch 4/15
# 875/875 [==============================] - 12s 14ms/step - loss: 2.6946e-05 - accuracy: 1.0000 - val_loss: 0.6512 - val_accuracy: 0.9279
# Epoch 5/15
# 875/875 [==============================] - 12s 14ms/step - loss: 2.3171e-05 - accuracy: 1.0000 - val_loss: 0.6552 - val_accuracy: 0.9265
# Epoch 6/15
# 875/875 [==============================] - 11s 13ms/step - loss: 2.0540e-05 - accuracy: 1.0000 - val_loss: 0.6587 - val_accuracy: 0.9265
# 108/108 [==============================] - 3s 28ms/step - loss: 0.5920 - accuracy: 0.9318
# ########################################################
# Iteración 9 de 10
# ########################################################
# Epoch 1/15
# 875/875 [==============================] - 39s 45ms/step - loss: 1.4426 - accuracy: 0.4219 - val_loss: 1.1564 - val_accuracy: 0.5776
# Epoch 2/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.9164 - accuracy: 0.6567 - val_loss: 0.7734 - val_accuracy: 0.7048
# Epoch 3/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.5958 - accuracy: 0.7838 - val_loss: 0.5922 - val_accuracy: 0.7925
# Epoch 4/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.3803 - accuracy: 0.8648 - val_loss: 0.4008 - val_accuracy: 0.8667
# Epoch 5/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.2520 - accuracy: 0.9110 - val_loss: 0.3870 - val_accuracy: 0.8741
# Epoch 6/15
# 875/875 [==============================] - 40s 45ms/step - loss: 0.1830 - accuracy: 0.9351 - val_loss: 0.4498 - val_accuracy: 0.8558
# Epoch 7/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.1239 - accuracy: 0.9564 - val_loss: 0.3094 - val_accuracy: 0.9156
# Epoch 8/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0722 - accuracy: 0.9765 - val_loss: 0.3277 - val_accuracy: 0.9184
# Epoch 9/15
# 875/875 [==============================] - 40s 46ms/step - loss: 0.0758 - accuracy: 0.9756 - val_loss: 0.3865 - val_accuracy: 0.9054
# Epoch 10/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0778 - accuracy: 0.9750 - val_loss: 0.3651 - val_accuracy: 0.9129
# Epoch 11/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0594 - accuracy: 0.9810 - val_loss: 0.3521 - val_accuracy: 0.9231
# Epoch 12/15
# 875/875 [==============================] - 39s 45ms/step - loss: 0.0135 - accuracy: 0.9962 - val_loss: 0.3877 - val_accuracy: 0.9245
# 3429
# 108/108 [==============================] - 3s 27ms/step - loss: 0.3813 - accuracy: 0.9291
# Epoch 1/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.3987 - val_accuracy: 0.9286
# Epoch 2/15
# 875/875 [==============================] - 12s 13ms/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.3907 - val_accuracy: 0.9333
# Epoch 3/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4188 - val_accuracy: 0.9286
# Epoch 4/15
# 875/875 [==============================] - 12s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4082 - val_accuracy: 0.9327
# Epoch 5/15
# 875/875 [==============================] - 11s 13ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.9299
# Epoch 6/15
# 875/875 [==============================] - 12s 13ms/step - loss: 9.3828e-04 - accuracy: 1.0000 - val_loss: 0.4281 - val_accuracy: 0.9361
# Epoch 7/15
# 875/875 [==============================] - 12s 13ms/step - loss: 8.3535e-04 - accuracy: 1.0000 - val_loss: 0.4367 - val_accuracy: 0.9354
# 108/108 [==============================] - 3s 28ms/step - loss: 0.4534 - accuracy: 0.9390
# ########################################################
# Iteración 10 de 10
# ########################################################

# %%
def run_train(nn_base_arch,epochs,checkpoint,dense = False):
    nn = select_network(nn_base_arch)
    
    if dense == True :
        model = build_dense(nn)
    else:
        model = build(nn)
        
    cpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint, monitor="val_loss", mode="min", save_best_only=True, verbose=0)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy','mse'])
    
    history = model.fit(x_train, y_train,epochs=EPOCHS,callbacks=[cpoint],batch_size = BATCH_SIZE,verbose=0)
      
    evaluation = model.evaluate(x_test, y_test)
        
    return history,evaluation

def run_train_w_model(model,epochs,output_layer):
        
    opt = tf.keras.optimizers.Adam(learning_rate=0.001,amsgrad=True)
    
    cbs = tf.keras.callbacks.LearningRateScheduler(scheduler)
        
    earlyStopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                patience = 3,
                                                mode = 'min')    
    
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    history = model.fit(x_train, y_train,validation_data=(x_validation, y_validation),epochs=epochs,
                        callbacks=[earlyStopping,cbs],batch_size = BATCH_SIZE)
    
    print(len(x_test))
    
    evaluation = model.evaluate(x_test, y_test)
        
    return history,evaluation,model
    
def re_train(model,checkpoint,epochs):
    
    cbs = tf.keras.callbacks.LearningRateScheduler(scheduler)
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.001,amsgrad=True)

    earlyStopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                                patience = 3,
                                                mode = 'min')    
    
    cpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint,
                                                monitor="val_loss",
                                                mode="min",
                                                save_best_only=True,
                                                verbose=0)
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    history = model.fit(x_train, y_train,validation_data=(x_validation, y_validation),epochs=epochs,callbacks=[earlyStopping,cbs,cpoint],batch_size = BATCH_SIZE)
    evaluation = model.evaluate(x_test, y_test)
    return history,evaluation,model

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
def run_experiment(index_model,epoch,iterations = ITERATIONS_PER_EXP):
    result = []
    result_post_tf = []
    evaluations = []
    evaluations_post_tf = []
    dense = False
    
    for i in range(iterations):
        checkpoint ="../TFG/Modelos/balanced_model_functionalv2.h5"
        
        if index_model == 0:
            model = full_build_cnn_soco(withBatchNormalization = False, withDropout=True)
        if index_model == 1:
            model = full_build_cnn_soco(withBatchNormalization = True, withDropout=True)
        if index_model == 2:
            model = full_build_cnn_soco(withBatchNormalization = True, withDropout=False)
        
        h,e,tf_model = run_train_w_model(model,epoch,dense)
        
        result.append(h)
        evaluations.append(e)

        layers = tf_model.layers[0:-1]
        for layer in layers:
            layer.trainable = False
            
        h_retrain,e_retrain,model = re_train(tf_model,checkpoint,epoch)

        result_post_tf.append(h_retrain)
        evaluations_post_tf.append(e_retrain)
        
        
        
        print("########################################################")
        print("Iteración "+str(i+1) +" de "+ str(iterations))
        print("########################################################")
        
    return result,result_post_tf,evaluations,evaluations_post_tf

# %% [markdown]
# ## Métodos de representación gráfica

# %%
def plot_acc_for_ex1_w_test_score(res,evaluations,epochs,name):
    plt.figure(figsize=(12,8))
    
    for i in range(len(res)):
        precisiones=[]
        precisiones.append(0.0)
        for e in res[i].history["accuracy"]:
            precisiones.append(e)
            
        plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1], label="train_acc")
        plt.plot(5,evaluations[i][1],'bo')
        
    plt.title("Training Loss and Accuracy - {}".format(name))
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.legend()
    plt.show()

# %%
def plot_acc_for_ex1(res,epochs,name):
    plt.figure(figsize=(12,8))
    
    for i in range(len(res)):
        precisiones=[]
        precisiones.append(0.0)
        for e in res[i].history["accuracy"]:
            precisiones.append(e)
            
        plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1], label="train_acc")
    plt.title("Training Loss and Accuracy - {}".format(name))
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.legend()
    plt.show()

# %%
def plot_acc_for_experiments(res,res1,evaluations,evaluations1,epochs,name):
    plt.figure(figsize=(12,8))
    
    for i in range(len(res)):
        precisiones=[]
        precisiones.append(0.0)
        for e in res[i].history["accuracy"]:
            precisiones.append(e)
        
        precisiones1=[]
        precisiones1.append(0.0)
        for e in res1[i].history["accuracy"]:
            precisiones1.append(e)
        
        if i == 0:
            plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1], label="train_acc",color='green')
            plt.plot(np.arange(0, epochs+1), precisiones1[0:epochs+1], label="train_acc",color='blue')
        else:
            plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1],color='green')
            plt.plot(np.arange(0, epochs+1), precisiones1[0:epochs+1],color='blue')
            plt.plot(5,evaluations[i][1],'bo',color='green')
            plt.plot(5,evaluations1[i][1],'bo',color='blue')
        
    plt.title("Training Loss and Accuracy - {}".format(name))
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.savefig("Exp_1_"+"Training "+str(value)+" and validation "+str(value)+".jpg")
    plt.legend()
    plt.show()

# %%
def plot_trainAcc_vs_valAcc_for_experiments(res,res1,epochs,name,value="loss"):
    plt.figure(figsize=(12,8))
    
    for i in range(len(range(5))):
        precisiones=[]
        precisiones.append(0.0)
        for e in res[i].history[value]:
            precisiones.append(e)
            
        #precisiones.append(0.0)
        for e in res1[i].history[value]:
            precisiones.append(e)
        
        precisiones1=[]
        precisiones1.append(0.0)
        for e in res[i].history["val_"+str(value)]:
            precisiones1.append(e)

        #precisiones1.append(0.0)
        for e in res1[i].history["val_"+str(value)]:
            precisiones1.append(e)
        
        if i == 0:
            plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1], label="train_"+str(value),color='green')
            plt.plot(np.arange(0, epochs+1), precisiones1[0:epochs+1], label="val_"+str(value),color='blue')
        else:
            plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1],color='green')
            plt.plot(np.arange(0, epochs+1), precisiones1[0:epochs+1],color='blue')
        
    plt.title("Training "+str(value)+" and validation "+str(value))
    plt.xlabel("Epoch")
    plt.ylabel(str(value).capitalize())
    plt.legend()
    plt.savefig("Exp_1_BN_"+"Training "+str(value)+" and validation "+str(value)+".jpg")
    plt.show()

# %%
plot_trainAcc_vs_valAcc_for_experiments(res31,res32,17,"","accuracy")

# %% [markdown]
# ## Representamos gráficamente los resultados obtenidos al experimentar con el tamaño del lote

# %%
def compute_values(resx1,resx2,i,val):
    res=[]
    if val != "val_loss":
        res.append(0.0)
    for e in resx1[i].history[val]:
        res.append(e)
    for e in resx2[i].history[val]:
        res.append(e)
    return res




def plot_acc_all_experiments(res11,res12,res21,res22,res31,res32,epochs):
    plt.figure(figsize=(16,10))
    
    acc = "val_accuracy"
    
    for i in range(10):
        
        precisiones = compute_values(res11,res12,i,acc)
            
        precisiones1 = compute_values(res21,res22,i,acc)
        
        precisiones2 = compute_values(res31,res32,i,acc)
        
        
        loss = compute_values(res11,res12,i,"val_loss")
        
        loss1 = compute_values(res21,res22,i,"val_loss")
        
        loss2 = compute_values(res31,res32,i,"val_loss")
        

        if i == 0:
            plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1], label="Dropout",color='green')
            #plt.plot(np.arange(0, epochs+1), precisiones1[0:epochs+1], label="BachNormalization y Dropout",color='blue')
            plt.plot(np.arange(0, epochs+1), precisiones2[0:epochs+1], label="BachNormalization sin Dropout",color='red')
            #plt.plot(np.arange(0, epochs+1), precisiones3[0:epochs+1], label="Amsgrad",color='aqua')
            #plt.plot(np.arange(0, epochs+1), precisiones4[0:epochs+1], label="Adamax",color='red')
            #plt.plot(np.arange(0, epochs+1), precisiones5[0:epochs+1], label="Nadam",color='deeppink')
            #plt.plot(np.arange(0, epochs+1), precisiones6[0:epochs+1], label="Adadelta",color='yellowgreen')
            
            plt.plot(np.arange(0, epochs+1), loss[0:epochs+1],color='green')
            #plt.plot(np.arange(0, epochs+1), loss1[0:epochs+1],color='blue')
            plt.plot(np.arange(0, epochs+1), loss2[0:epochs+1],color='red')
            #plt.plot(np.arange(0, epochs+1), loss3[0:epochs+1],color='aqua')
            #plt.plot(np.arange(0, epochs+1), loss4[0:epochs+1], label="Adamax",color='red')
            #plt.plot(np.arange(0, epochs+1), loss5[0:epochs+1], label="Nadam",color='deeppink')
            #plt.plot(np.arange(0, epochs+1), loss6[0:epochs+1], label="Adadelta",color='yellowgreen')
            
        else:
            
            plt.plot(np.arange(0, epochs+1), precisiones[0:epochs+1],color='green')
            #plt.plot(np.arange(0, epochs+1), precisiones1[0:epochs+1],color='blue')
            plt.plot(np.arange(0, epochs+1), precisiones2[0:epochs+1],color='red')
            #plt.plot(np.arange(0, epochs+1), precisiones3[0:epochs+1],color='aqua')
            #plt.plot(np.arange(0, epochs+1), precisiones4[0:epochs+1], label="Adamax",color='red')
            #plt.plot(np.arange(0, epochs+1), precisiones5[0:epochs+1], label="Nadam",color='deeppink')
            #plt.plot(np.arange(0, epochs+1), precisiones6[0:epochs+1], label="Adadelta",color='yellowgreen')
            
            plt.plot(np.arange(0, epochs+1), loss[0:epochs+1],color='green')
            #plt.plot(np.arange(0, epochs+1), loss1[0:epochs+1],color='blue')
            plt.plot(np.arange(0, epochs+1), loss2[0:epochs+1],color='red')
            #plt.plot(np.arange(0, epochs+1), loss3[0:epochs+1],color='aqua')
            #plt.plot(np.arange(0, epochs+1), loss4[0:epochs+1],color='red')
            #plt.plot(np.arange(0, epochs+1), loss5[0:epochs+1],color='deeppink')
            #plt.plot(np.arange(0, epochs+1), loss6[0:epochs+1],color='yellowgreen')
            
        del precisiones
        del precisiones1
        del precisiones2


        
    plt.title("Training Accuracy and Test Results")
    plt.xlabel("Epoch")
    plt.ylabel("Loss/Accuracy")
    plt.legend()
    plt.savefig("Exp_1_2_kinds.jpg")
    plt.show()
#RMSProp,SGD,Adam,Amsgrad,Adamax,Nadam,Adadelta

# %%
plot_acc_all_experiments(res11,res12,res21,res22,res31,res32,16)

# %% [markdown]
# ## Creamos marcos de datos para analizar los resultados de evaluar los modelos

# %%
precision1 = []
precision2 = []
precision3 = []
precision4 = []
precision5 = []


for e in evaluations1:
    element = e[1]
    precision1.append(element)
    
for e in evaluations2:
    element = e[1]
    precision2.append(element)
    
for e in evaluations3:
    element = e[1]
    precision3.append(element)


    
#RMSProp,SGD,Adam,Amsgrad,Adamax,Nadam,Adadelta    
    
d = {'Dropout': precision1,'BachNormalization y Dropout': precision2,'BachNormalization sin Dropout':precision3}
df = pd.DataFrame(data=d)

print(df)
print(df.mean())
# Out:
#     Dropout  BachNormalization y Dropout  BachNormalization sin Dropout
# 0  0.925926                     0.910178                       0.932925
# 1  0.921260                     0.925343                       0.938174
# 2  0.927384                     0.923301                       0.927676
# 3  0.929425                     0.916010                       0.932925
# 4  0.931175                     0.916594                       0.924176
# 5  0.932050                     0.924468                       0.932925
# 6  0.927384                     0.920968                       0.933800
# 7  0.929717                     0.885389                       0.933508
# 8  0.929717                     0.930009                       0.931759
# 9  0.936716                     0.919510                       0.939049
# Dropout                          0.929076
# BachNormalization y Dropout      0.917177
# BachNormalization sin Dropout    0.932692
# dtype: float64
